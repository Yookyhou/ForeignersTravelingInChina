# %% [markdown]
# ### 步骤 1：数据准备
#
# 1. 读取GeoNames数据库文件：
#    - 下载并读取包含城市信息的GeoNames数据库文件。
#    - 筛选出中国的城市并提取其名称和地理坐标。
# 2. 获取和处理文件名：
#    - 从指定目录中获取所有文件名，并去掉扩展名，得到城市名称。
#    - 将中文城市名转换为拼音，并将每个字符串的首字母大写。
#    - 构成二元组的列表并转换为字典，用于后续的查找。
# 3. 读取和筛选目标城市数据：
#    - 读取“最令外国游客向往的50个城市”的名单，并转换为拼音。

# %%
import pandas as pd
import os
from pypinyin import lazy_pinyin
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 下载GeoNames数据库文件并筛选中国的城市
url = 'cities1000.txt'
cities_data = pd.read_csv(url, sep='\t', names=[
    'geonameid', 'name', 'asciiname', 'alternatenames', 'latitude', 'longitude',
    'feature class', 'feature code', 'country code', 'cc2', 'admin1 code',
    'admin2 code', 'admin3 code', 'admin4 code', 'population', 'elevation',
    'dem', 'timezone', 'modification date'
])
china_cities_coordinates = cities_data[cities_data['country code'] == 'CN'][['name', 'latitude', 'longitude']]
print(china_cities_coordinates.head())

# 获取目录下文件名（去掉扩展名）
def get_filenames_without_extension(directory_path):
    try:
        return [os.path.splitext(item)[0] for item in os.listdir(directory_path) if os.path.isfile(os.path.join(directory_path, item))]
    except Exception as e:
        print(f"error: {e}")
        return []

directory_path = "附件"  
filenames = get_filenames_without_extension(directory_path)
print(filenames, len(filenames))

# 转换文件名为拼音并首字母大写
pinyin_filenames = [''.join(lazy_pinyin(city)).capitalize() for city in filenames]
print(pinyin_filenames, len(pinyin_filenames))

# 构成二元组的列表并转换为字典
city_tuples = list(zip(pinyin_filenames, filenames)) 
city_dict = dict(city_tuples)
print(city_dict)

# 根据拼音文件名查找中国城市
filtered_df = china_cities_coordinates[china_cities_coordinates['name'].isin(pinyin_filenames)]

# 新增一列“城市”并去重
filtered_df['城市'] = filtered_df['name'].map(city_dict)
filtered_df = filtered_df.drop_duplicates(subset=['城市'])
print(filtered_df)
# Out:
#             name  latitude  longitude
# 20945     Zongga  29.00000   85.25000
# 20946       Zito  30.73893   95.83613
# 20947  Zhowagoin  28.65910   97.45065
# 20948    Zhefang  24.26667   98.28333
# 20949     Zhedao  24.81934   98.27627
# ['定西', '韶关', '银川', '眉山', '琼中', '盘锦', '固原', '滁州', '东营', '恩施', '文山', '安顺', '龙岩', '商丘', '潜江', '广州', '汕尾', '乐山', '淮北', '大连', '厦门', '双河', '博尔塔拉', '五家渠', '屯昌', '宜春', '平顶山', '鹤壁', '三明', '呼和浩特', '永州', '苏州', '丽水', '乌兰察布', '三亚', '泉州', '绍兴', '晋城', '温州', '中卫', '郑州', '兰州', '淮南', '牡丹江', '雄安新区', '佛山', '台州', '阿勒泰', '大兴安岭', '石家庄', '伊春', '阿拉善盟', '德宏', '抚州', '许昌', '阿拉尔', '南昌', '六安', '太原', '可克达拉', '湛江', '阳江', '怀化', '河池', '普洱', '西安', '湘潭', '玉溪', '商洛', '临沧', '沈阳', '岳阳', '潍坊', '五指山', '舟山', '徐州', '巢湖', '铁门关', '烟台', '陵水', '黔西南', '娄底', '定安', '庆阳', '嘉峪关', '荆州', '白山', '六盘水', '湘西', '七台河', '攀枝花', '吐鲁番', '海口', '太湖', '红河', '常德', '渭南', '吉安', '珠海', '淄博', '扬州', '松原', '玉林', '衢州', '双鸭山', '包头', '林芝', '保亭', '清远', '宜宾', '滨州', '黄山', '芜湖', '天津', '那曲', '揭阳', '驻马店', '白沙', '济南', '曲靖', '唐山', '鹰潭', '郴州', '梅州', '迪庆', '贵阳', '临沂', '东莞', '衡水', '乐东', '云浮', '绥化', '江门', '连云港', '咸宁', '铜陵', '乌鲁木齐', '张家界', '宣城', '和田', '蚌埠', '泰安', '张家口', '安阳', '茂名', '鸡西', '柳州', '惠州', '运城', '泸州', '淮安', '吴忠', '黄冈', '楚雄州', '长白山', '天门', '漯河', '枣庄', '自贡', '石河子', '邢台', '遵义', '喀什', '辽源', '钦州', '南京', '湖州', '宁波', '临高', '东方', '上饶', '榆林', '金华', '坝上', '襄阳', '梧州', '衡阳', '吉林市', '德阳', '邵阳', '临汾', '汉中', '巴音郭楞', '忻州', '兴安盟', '崇左', '南宁', '铜仁', '日照', '金昌', '鄂州', '贺州', '宝鸡', '拉萨', '哈尔滨', '濮阳', '万宁', '亳州', '山南', '阿坝', '呼伦贝尔', '萍乡', '阿克苏', '克孜勒苏柯尔克孜', '重庆', '廊坊', '赤峰', '抚顺', '澄迈', '昆明', '河源', '三门峡', '武汉', '晋中', '宜昌', '白银', '嘉兴', '雅安', '洛阳', '南充', '朔州', '昌江', '阳泉', '黔东南', '莆田', '齐齐哈尔', '丽江', '阜阳', '合肥', '莱芜', '陇南', '遂宁', '张掖', '吕梁', '天水', '仙桃', '长沙', '保定', '石嘴山', '延安', '中山', '随州', '铜川', '九江', '昌吉', '图木舒克', '孝感', '青木川', '福州', '肇庆', '凉山', '常州', '信阳', '武功山', '杭州', '开封', '焦作', '赣州', '日喀则', '新余', '秦皇岛', '漳州', '广元', '安康', '德州', '宿州', '广安', '铁岭', '毕节', '昆玉', '大理', '本溪', '北京', '伊犁', '上海', '锡林郭勒盟', '克拉玛依', '鹤岗', '黑河', '大同', '昭通', '宿迁', '安庆', '北海', '青岛', '酒泉', '大庆', '南阳', '三沙', '黔南', '景德镇', '巴中', '鞍山', '巴彦淖尔', '丹东', '塔城', '十堰', '周口', '保山', '神农架', '菏泽', '桂林', '株洲', '延边', '阜新', '来宾', '马鞍山', '黄石', '武威', '威海', '百色', '佳木斯', '济源', '宁德', '通化', '聊城', '无锡', '达州', '琼海', '内江', '阿里', '长治', '济宁', '辽阳', '贵港', '白城', '通辽', '潮州', '深圳', '咸阳', '南通', '北屯', '新乡', '泰州', '哈密', '朝阳', '承德', '怒江', '成都', '鄂尔多斯', '儋州', '绵阳', '防城港', '西双版纳', '营口', '甘孜', '葫芦岛', '四平', '汕头', '资阳', '益阳', '沧州'] 352
# 25184          Baoji  34.36775  107.23705   宝鸡
# 25204       Chongzuo  22.38161  107.36830   崇左
# 25219  Fangchenggang  21.76945  108.35661  防城港
# 25299          Hechi  24.69285  108.08376   河池
# 25392         Sansha  16.83912  112.34064   三沙
#
# [269 rows x 4 columns]

# %% [markdown]
# ### 步骤 2：筛选和合并数据
#
# 4. 根据拼音查找城市：
#    - 根据拼音文件名在中国城市坐标数据中进行查找，并创建新的DataFrame。
#    - 新增一列“城市”存放城市的中文名，并去重。
# 5. 读取和筛选景点数据：
#    - 读取指定目录下的所有CSV文件，提取其中评分为5.0的景点。
#    - 将筛选出的景点数据合并到一个DataFrame中。
# 6. 更新景点信息：
#    - 初始化新的列（如“建议游玩时间”、“门票”）。
#    - 遍历CSV文件，更新DataFrame中的对应列。
#
# ### 步骤 3：数据处理和转换
#
# 7. 处理建议游玩时间：
#    - 将建议游玩时间字段中的值转换为最小小时数。
#    - 例如：“建议游览时间：1天 - 2天” 转换为 24小时。
# 8. 处理门票价格：
#    - 将门票字段中的值转换为具体的票价，并处理特殊情况（如免费、具体收费情况等）。
#    - 填充缺失的门票价格，并将其转换为整数类型。
#    - 例如：“50元” 转换为 50。

# %%
import pandas as pd
from pypinyin import lazy_pinyin

# 读取数据
top50 = pd.read_csv('最令外国游客向往的50个城市（AHP）最终版.csv')
top50 = top50['来源城市'].values

# 将中文城市名转换为拼音并首字母大写
capitalized_50 = [''.join(lazy_pinyin(city)).capitalize() for city in top50]

# 构成二元组的列表并转换为字典
city50_tuples = list(zip(capitalized_50, top50))
city_dict = dict(city50_tuples)

# 根据 capitalized_filenames 进行查找
filtered50_df = china_cities_coordinates[china_cities_coordinates['name'].isin(capitalized_50)]

# 新增一列“城市”，存放城市的中文名
filtered50_df['城市'] = filtered50_df['name'].map(city_dict)
filtered50_df = filtered50_df.drop_duplicates(subset=['城市'])

# 去掉索引为 21393 的行
filtered50_df = filtered50_df.drop(index=21393, errors='ignore')

# 输出结果
print(filtered50_df, filtered50_df.shape)
# Out:
#             name  latitude  longitude   城市
# 21050  Jiayuguan  39.81121   98.28618  嘉峪关
# 21155   Baicheng  41.77389   81.86889   白城
# 21278  Zhongshan  24.52913  111.29704   中山
# 21392   Yuncheng  35.59833  115.93472   运城
# 21417  Qianjiang  30.42100  112.89190   潜江
# 21523   Yangzhou  32.39722  119.43583   扬州
# 21605    Xinzhou  38.40917  112.73333   忻州
# 21730   Xianning  29.84347  114.32201   咸宁
# 21734     Zhuhai  22.27694  113.56778   珠海
# 21792    Changde  29.03205  111.69844   常德
# 21846    Weifang  36.71000  119.10194   潍坊
# 21948   Tangshan  39.63333  118.18333   唐山
# 21960    Taizhou  32.49069  119.90812   台州
# 21980     Suqian  33.94917  118.29583   宿迁
# 22018   Shuozhou  39.31583  112.42250   朔州
# 22138    Shanwei  22.78199  115.34750   汕尾
# 22178      Sanya  18.25435  109.50947   三亚
# 22457   Nanchong  30.79508  106.08473   南充
# 22508    Meishan  31.72913  115.91241   眉山
# 22549     Luzhou  28.89030  105.42575   泸州
# 22717     Lingao  19.90873  109.68717   临高
# 22725    Lijiang  23.57110  102.00417   丽江
# 22817     Jiyuan  35.09000  112.58000   济源
# 22887   Jincheng  35.50222  112.83278   晋城
# 22954   Qionghai  19.24250  110.46417   琼海
# 22972    Huizhou  23.11147  114.41523   惠州
# 23112   Hangzhou  30.29365  120.16142   杭州
# 23154    Guiyang  26.58333  106.71667   贵阳
# 23244     Fuzhou  27.95999  116.33333   福州
# 23312      Enshi  30.30000  109.48333   恩施
# 23376     Dingxi  35.57088  104.62303   定西
# 23453       Dali  34.79586  109.93895   大理
# 23531    Chengdu  30.66667  104.06667   成都
# 23616    Beijing  39.90750  116.39723   北京
# 23640   Shaoyang  27.23818  111.46214   邵阳
# 23697     Anqing  30.51365  117.04723   安庆
# 23995    Tonghua  41.71972  125.92639   通化
# 24026   Shenyang  41.79222  123.43278   沈阳
# 24126    Jiamusi  46.79711  130.31118  佳木斯
# 24168      Fuxin  42.01556  121.65889   阜新
# 24223     Baotou  40.65160  109.84389   包头
# 24282  Panzhihua  26.58509  101.71276  攀枝花
# 24495     Hezhou  24.40357  111.56675   贺州
# 25184      Baoji  34.36775  107.23705   宝鸡 (44, 4)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import matplotlib.font_manager as fm

font_path = '/System/Library/Fonts/PingFang.ttc'
font_prop = fm.FontProperties(fname=font_path)

# 创建绘制图
plt.figure(figsize=(12, 8))

# 创建 Basemap 地图
m = Basemap(projection='merc', llcrnrlat=15, urcrnrlat=55, llcrnrlon=70, urcrnrlon=140, resolution='i')
m.drawcoastlines()
m.drawcountries()
m.drawmapboundary(fill_color='aqua')
m.fillcontinents(color='lightyellow', lake_color='aqua')
m.drawparallels(range(0, 90, 10), labels=[1,0,0,0])
m.drawmeridians(range(0, 180, 10), labels=[0,0,0,1])

# 在地图上添加城市标记
for _, city in filtered50_df.iterrows():
    x, y = m(city['longitude'], city['latitude'])
    m.plot(x, y, 'bo', markersize=8)
    plt.text(x, y, city['城市'], fontsize=12, fontproperties=font_prop, ha='left', va='bottom')

# 设置标题
plt.title("中国城市地图", fontsize=20, fontproperties=font_prop)

# 显示图
plt.show()

# %%
# 广州的经纬度
guangzhou_lat = 23.1291
guangzhou_lon = 113.2644

# 创建绘制图
plt.figure(figsize=(12, 8))

# 创建 Basemap 地图
m = Basemap(projection='merc', llcrnrlat=15, urcrnrlat=55, llcrnrlon=70, urcrnrlon=140, resolution='i')
m.drawcoastlines()
m.drawcountries()
m.drawmapboundary(fill_color='aqua')
m.fillcontinents(color='lightyellow', lake_color='aqua')
m.drawparallels(range(0, 90, 10), labels=[1,0,0,0])
m.drawmeridians(range(0, 180, 10), labels=[0,0,0,1])

# 在地图上添加城市标记
for _, city in filtered50_df.iterrows():
    x, y = m(city['longitude'], city['latitude'])
    m.plot(x, y, 'bo', markersize=8)
    plt.text(x, y, city['城市'], fontsize=12, fontproperties=font_prop, ha='left', va='bottom')

# 在地图中标出广州
x, y = m(guangzhou_lon, guangzhou_lat)
m.plot(x, y, 'ro', markersize=10)
plt.text(x, y, '广州', fontsize=14, fontproperties=font_prop, ha='left', va='bottom', color='red')

# 设置标题
plt.title("中国城市地图", fontsize=20, fontproperties=font_prop)

# 显示图
plt.show()

# %%
# 查看评分和建议游玩时间中包含的所有可能值
directory = '附件'
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        city_data = pd.read_csv(os.path.join(directory, filename))
        unique_values_menpiao = city_data['门票'].unique()
        unique_values_youwan = city_data['建议游玩时间'].unique()
        print(f"{filename} - 门票: {unique_values_menpiao}")
        print(f"{filename} - 建议游玩时间: {unique_values_youwan}")

# 存放结果的DataFrame
result_df = pd.DataFrame(columns=['City', '名字', '评分'])

# 遍历附件目录中的所有CSV文件
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        city_name = filename[:-4]  # 去掉文件后缀，得到城市名称
        city_data = pd.read_csv(os.path.join(directory, filename))

        # 去掉NaN和'--'值，并将评分转换为float类型
        city_data['评分'] = city_data['评分'].replace('--', np.nan).dropna().astype(float)
        
        # 找到评分为5.0的景点
        high_score_spots = city_data[city_data['评分'] == 5.0]
        
        # 仅在存在评分为5.0的景点时处理
        if not high_score_spots.empty:
            high_score_spots = high_score_spots.copy()  # 避免 SettingWithCopyWarning
            high_score_spots['City'] = city_name  # 直接修改 DataFrame
            result_df = pd.concat([result_df, high_score_spots[['City', '名字', '评分']]], ignore_index=True)

# 输出结果
print(result_df)

# 找到result_df中City在filtered50_df中的城市
filtered_cities = filtered50_df['城市'].unique()
filtered_result_df = result_df[result_df['City'].isin(filtered_cities)]
print(filtered_result_df)
# Out:
# 定西.csv - 门票: ['门票：15元；云麓宫5元；麓山寺5元；鸟语林20元 成人团体票：12元/人；学生团体票：10/人' nan
#  "{'贵清山旅游风景区门票成人票\\n\\n': ['¥50起'], '贵清山旅游风景区门票老人票\\n\\n': ['¥25起'], '贵清山旅游风景区门票优待票\\n\\n': ['¥25起']}"
#  '具体收费情况以现场公示为主' '20元' '25元' '免费' '收费' '目前景区暂未开启线上购票渠道，游客需至景区现场购票入园。'
#  '40元']
# 定西.csv - 建议游玩时间: [nan '建议游览时间：3小时 - 5小时' '建议游览时间：2小时 - 3小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：1小时 - 3小时' '建议游览时间：1小时 - 2小时' '建议游览时间：3小时' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：3天' '建议游览时间：2小时']
# 韶关.csv - 门票: ["{'丹霞山门票成人票\\n\\n': ['¥50起'], '水上丹霞游船票成人票\\n\\n': ['¥110起'], '丹霞山索道单程（上行）票成人票\\n\\n': ['¥39起']}"
#  '具体收费情况以现场公示为主' '免费' "{'南岭国家森林公园电子讲解导览服务成人票\\n\\n': ['¥9起']}"
#  "{'广东大峡谷门票成人票\\n\\n': ['¥54.8起'], '广东大峡谷门票优待票\\n\\n': ['¥35起'], '广东大峡谷门票双人票\\n\\n': ['¥110起']}"
#  nan '包含于丹霞山风景名胜区景区门票内，通用于丹霞山风景名胜区景区门票。'
#  "{'云门寺电子导览服务大小同价\\n\\n': ['¥9起']}" "{'金鸡岭门票成人票\\n\\n': ['¥35起']}"
#  '上午138元,下午168元' '40元'
#  "{'珠玑古巷门票成人票\\n\\n': ['¥38起'], '珠玑古巷门票优待票\\n\\n': ['¥20起'], '南雄珠玑古巷电子导览服务大小同价\\n\\n': ['¥1起']}"
#  "{'帽子峰旅游景区门票成人票\\n\\n': ['¥25起'], '帽子峰旅游景区凌江游船包船票成人票\\n\\n': ['¥95起'], '韶关丹霞山+帽子峰旅游景区年卡优待票\\n\\n': ['¥98起']}"
#  "{'云髻山电子导览服务大小同价\\n\\n': ['¥7起']}"
#  "{'仙门奇峡门票成人票\\n\\n': ['¥76起'], '仙门奇峡门票优待票\\n\\n': ['¥45起'], '仙门奇峡门票家庭票(2大1小)\\n\\n': ['¥197起']}"
#  '50元（草原和飞水寨）' "{'韶石山手机智能导游讲解服务大小同价\\n\\n': ['¥7起']}"
#  "{'韶关恐龙博物馆门票大小同价\\n\\n': ['¥35起']}"
#  "{'古佛岩门票成人票\\n\\n': ['¥55起'], '古佛岩古佛通天玻璃滑道票成人票\\n\\n': ['¥30起'], '古佛岩电子导览服务大小同价\\n\\n': ['¥6起']}"
#  '成人票40元，儿童1.2米以下免票，70周岁以上老人凭有效证件免票，军官凭证件免票。']
# 韶关.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' '建议游览时间：2小时 - 3小时' nan '建议游览时间：1小时' '建议游览时间：3天'
#  '建议游览时间：12小时' '建议游览时间：1小时 - 2小时' '建议游览时间：5小时 - 6小时' '建议游览时间：2小时'
#  '建议游览时间：1小时 - 1天' '建议游览时间：3小时 - 6小时' '建议游览时间：3小时' '建议游览时间：4小时'
#  '建议游览时间：12小时 - 3天']
# 银川.csv - 门票: [nan
#  "{'镇北堡西部影城门票成人票\\n\\n': ['¥76起'], '镇北堡西部影城门票儿童票\\n\\n': ['¥40起'], '镇北堡西部影城门票优待票\\n\\n': ['¥40起']}"
#  "{'西夏陵门票+往返观光车成人票\\n\\n': ['¥84.5起'], '西夏陵国家考古遗址公园门票+园内观光车票学生票\\n\\n': ['¥54起'], '西夏陵门票+3D电影+往返观光车票成人票\\n\\n': ['¥108起']}"
#  "{'贺兰山岩画门票成人票\\n\\n': ['¥80起'], '贺兰山岩画门票+往返观光车票老人票\\n\\n': ['¥10起'], '贺兰山岩画门票+电瓶车票成人票\\n\\n': ['¥65起']}"
#  "{'贺兰山国家森林公园门票+往返观光车票成人票\\n\\n': ['¥75起'], '贺兰山国家森林公园门票+往返观光车票学生票\\n\\n': ['¥50起'], '贺兰山国家森林公园（苏峪口）+园内往返观光车票+银川市区往返景区直通车票成人票\\n\\n': ['¥148起']}"
#  "{'黄沙古渡原生态旅游区一票通套票成人票\\n\\n': ['¥198起'], '黄沙古渡原生态旅游区一票通套票学生票\\n\\n': ['¥188起'], '黄沙古渡原生态旅游区市区车费成人票\\n\\n': ['¥40起']}"
#  "{'宁夏博物馆0元预约票大小同价\\n\\n': ['¥20起'], '宁夏博物馆寻宝之旅体验票大小同价\\n\\n': ['¥169起'], '宁夏博物馆凤凰碗套装冰箱贴票大小同价\\n\\n': ['¥189起']}"
#  '30元' '具体收费情况以现场公示为主'
#  "{'水洞沟旅游区门票成人票\\n\\n': ['¥60起'], '水洞沟旅游区门票大小同价\\n\\n': ['¥1起'], '水洞沟旅游区门票学生票\\n\\n': ['¥30起']}"
#  '40元' '免费' '寺庙3元；爬塔18元'
#  "{'银川鸣翠湖国家湿地公园门票成人票\\n\\n': ['¥40起'], '银川鸣翠湖国家湿地公园门票学生票\\n\\n': ['¥20起'], '银川鸣翠湖国家湿地公园门票+船票+观光车（单程）成人票\\n\\n': ['¥68起']}"
#  "{'拜寺口双塔电子讲解票大小同价\\n\\n': ['¥7起']}"
#  "{'滚钟口门票成人票\\n\\n': ['¥30起'], '滚钟口门票学生票\\n\\n': ['¥20起'], '贺兰山滚钟口电子导览服务大小同价\\n\\n': ['¥9起']}"
#  "{'黄河军事文化博览园门票成人票\\n\\n': ['¥50起'], '黄河军事文化博览园门票学生票\\n\\n': ['¥25起'], '黄河军事文化博览园潜艇票成人票\\n\\n': ['¥30起']}"
#  "{'阅海公园门票成人票\\n\\n': ['¥10起'], '阅海公园门票儿童票\\n\\n': ['¥5起']}" '收费'
#  '具体收费情况以景区现场公示为主。' '68元' '50元' '首道大门票收费情况请咨询景区'
#  "{'领新耘智·3D打印创新基地门票大小同价\\n\\n': ['¥19.9起']}"
#  "{'稻渔空间踏青季套票亲子票(1大1小)\\n\\n': ['¥158起']}"]
# 银川.csv - 建议游玩时间: [nan '建议游览时间：3小时 - 4小时' '建议游览时间：2小时 - 4小时' '建议游览时间：2小时 - 3小时' '建议游览时间：5小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：1小时' '建议游览时间：0.3小时 - 0.5小时' '建议游览时间：0.5小时'
#  '建议游览时间：2小时 - 5小时' '建议游览时间：1小时 - 3小时' '建议游览时间：0.7小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：2小时']
# 眉山.csv - 门票: ['具体收费情况以现场公示为主'
#  "{'瓦屋山风景区门票大小同价\\n\\n': ['¥10起'], '瓦屋山风景区门票+金花桥索道往返票成人票\\n\\n': ['¥185起'], '瓦屋山风景区门票+金花桥索道往返票优待票\\n\\n': ['¥138起']}"
#  "{'柳江古镇机导游(不含门票)手绘地图、语音讲解、路服务成人票\\n\\n': ['¥7起'], '成都周边游 瓦屋山+柳江古镇+槽渔滩纯玩两日游\\n\\n': ['¥239起']}"
#  '免费' "{'三苏祠门票成人票\\n\\n': ['¥40起']}" "{'中岩寺电子讲解票大小同价\\n\\n': ['¥7起']}"
#  "{'老峨山大门票成人票\\n\\n': ['¥38起'], '老峨山门票+往返观光车票成人票\\n\\n': ['¥58起'], '老峨山门票+往返观光车票优待票\\n\\n': ['¥40起']}"
#  nan '30元' '10元' '15元' "{'中国竹艺城手机智能导游讲解服务大小同价\\n\\n': ['¥5起']}" '8元'
#  "{'稻香湾梦幻田园门票大小同价\\n\\n': ['¥28起']}" '收费']
# 眉山.csv - 建议游玩时间: ['建议游览时间：3小时' '建议游览时间：3小时 - 5小时' '建议游览时间：9天 - 12天' nan '建议游览时间：2小时 - 3小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：1小时 - 3小时' '建议游览时间：0.5小时 - 2小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：1小时 - 4小时' '建议游览时间：12小时' '建议游览时间：2小时'
#  '建议游览时间：2小时 - 4小时' '建议游览时间：3小时 - 4小时']
# 琼中.csv - 门票: ['具体收费情况以现场公示为主'
#  "{'海南百花岭热带雨林文化旅游区门票+往返游览车票成人票\\n\\n': ['¥86.1起'], '海南百花岭热带雨林文化旅游区门票+往返游览车+雨林速滑套票成人票\\n\\n': ['¥168起'], '海南百花岭热带雨林文化旅游区门票+往返游览车+雨林速滑+树梢栈道套票成人票\\n\\n': ['¥231.5起']}"
#  nan]
# 琼中.csv - 建议游玩时间: ['建议游览时间：4小时' '建议游览时间：1小时 - 1天' nan '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：2小时 - 4小时' '建议游览时间：1小时 - 3小时' '建议游览时间：2小时' '建议游览时间：1小时']
# 盘锦.csv - 门票: ['98元' '具体收费情况以现场公示为主' nan "{'盘锦湖滨公园手机导游(不含门票)服务成人票\\n\\n': ['¥8起']}"
#  '具体收费情况以景区现场公示为主。' "{'盘锦森林公园电子导览服务大小同价\\n\\n': ['¥5起']}" '38元'
#  '含章湖旅游度假区无大门票，景区内每个项目单独收费。花海：35元；龙船/画舫：168元。' '景区免费开放，游船需收费，详情可咨询景区']
# 盘锦.csv - 建议游玩时间: ['建议游览时间：4小时 - 5小时' '建议游览时间：1小时' nan '建议游览时间：3小时' '建议游览时间：3小时 - 4小时'
#  '建议游览时间：1小时 - 3小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：2小时' '建议游览时间：3天 - 6天']
# 固原.csv - 门票: ["{'六盘山国家森林公园门票+景区内摆渡车票学生票\\n\\n': ['¥65起'], '六盘山国家森林公园电子导览服务成人票\\n\\n': ['¥2.6起']}"
#  '40元' nan '45元' '具体收费情况以现场公示为主' '20元' '48元' '168元' '65元' '50元'
#  '首道大门票收费情况请咨询景区' '免费' '具体收费情况以景区现场公示为主。']
# 固原.csv - 建议游玩时间: ['建议游览时间：3小时 - 4小时' '建议游览时间：12小时 - 3天' nan '建议游览时间：1小时' '建议游览时间：3小时'
#  '建议游览时间：3小时 - 5小时' '建议游览时间：2小时' '建议游览时间：1小时 - 3小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：0.5小时 - 2小时']
# 滁州.csv - 门票: [nan
#  "{'韭山洞门票成人票\\n\\n': ['¥45起'], '韭山洞门票儿童票\\n\\n': ['¥25起'], '韭山洞门票老人票\\n\\n': ['¥25起']}"
#  '免费' '包含于琅琊山景区内，通用琅琊山景区门票。' '具体收费情况以现场公示为主'
#  "{' 狼巷迷谷门票成人票\\n\\n': ['¥55起'], ' 狼巷迷谷门票儿童票\\n\\n': ['¥30起'], ' 狼巷迷谷门票学生票\\n\\n': ['¥30起']}"
#  "{'明皇陵门票成人票\\n\\n': ['¥45起'], '明皇陵门票儿童票\\n\\n': ['¥25起'], '明皇陵门票老人票\\n\\n': ['¥25起']}"
#  "{'皇甫山门票成人票\\n\\n': ['¥39起'], '皇甫山门票优待票\\n\\n': ['¥20起'], '皇甫山门票双人票\\n\\n': ['¥78起']}"
#  '30元' '16元' '免费公园。' "{'沙坝北公园欢乐农场体验大小同价\\n\\n': ['¥10起']}"
#  "{'琅琊山景区(醉翁亭+同乐园+琅琊寺+南天门)套票+南京太仆寺景区门票成人票\\n\\n': ['¥60起'], '南京太仆寺景区太仆寺+丰乐亭门票成人票\\n\\n': ['¥20起'], '【酒店套餐】南京涵田栖云山房酒店|坐落于南京栖霞山南麓，依山而建，有效期到23年6月底\\n\\n': ['¥1199起']}"]
# 滁州.csv - 建议游玩时间: [nan '建议游览时间：1小时 - 5小时' '建议游览时间：1小时' '建议游览时间：3天' '建议游览时间：1小时 - 6小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：1小时 - 3小时' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：3小时 - 5小时' '建议游览时间：3小时' '建议游览时间：12小时 - 3天']
# 东营.csv - 门票: [nan '免费' "{'清风湖公园电子导览服务大小同价\\n\\n': ['¥6起']}"
#  "{'黄河口生态旅游区手机导游(不含门票)服务大小同价\\n\\n': ['¥0.6起']}" '具体收费情况以现场公示为主' '5元'
#  "{'孙武祠电子导览票大小同价\\n\\n': ['¥6起']}"
#  "{'东营市历史博物馆驴迹电子导览（不含门票）服务大小同价\\n\\n': ['¥6起']}" '9元' '30元' '50元']
# 东营.csv - 建议游玩时间: ['建议游览时间：1小时 - 3小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时' '建议游览时间：3天'
#  '建议游览时间：1小时 - 2小时' nan '建议游览时间：12小时 - 3天' '建议游览时间：3天 - 6天'
#  '建议游览时间：0.5小时 - 2小时' '建议游览时间：2小时' '建议游览时间：6天']
# 恩施.csv - 门票: ["{'屏山峡谷+单程船票成人票\\n\\n': ['¥199起'], '鹤峰屏山峡谷门票+单程船票优待票\\n\\n': ['¥125起'], '恩施屏山峡谷一日游【上门接送 网红游船打卡 真纯玩无购物】\\n\\n': ['¥248起']}"
#  "{'恩施大峡谷七星寨景区+云龙地缝+垂梯票+恩施大峡谷扶梯+景区内交通（观光车+缆车）票+恩施大峡谷索道（上行）票学生票\\n\\n': ['¥292起'], '恩施大峡谷七星寨景区+云龙地缝+垂梯票+恩施大峡谷扶梯+景区内交通（观光车+缆车）票+恩施大峡谷索道（上行）票老人票\\n\\n': ['¥215起'], '恩施大峡谷七星寨景区+云龙地缝+垂梯票+恩施大峡谷扶梯+景区内交通（观光车+缆车）票+恩施大峡谷索道（上行）票优待票\\n\\n': ['¥292起']}"
#  "{'狮子关旅游区门票成人票\\n\\n': ['¥112起'], '狮子关旅游区门票优待票\\n\\n': ['¥60起'], '狮子关旅游区电子导览服务大小同价\\n\\n': ['¥7起']}"
#  "{'恩施地心谷景区（石门河）门票+车票+空中魔毯票大小同价\\n\\n': ['¥105起'], '恩施地心谷景区（石门河）门票+车票+玻璃桥+空中魔毯+观光电梯票大小同价\\n\\n': ['¥185起'], '恩施地心谷景区（石门河）门票+车票+空中魔毯+观光电梯票大小同价\\n\\n': ['¥135起']}"
#  "{'腾龙洞门票老人票\\n\\n': ['¥75起'], '腾龙洞门票成人票\\n\\n': ['¥150起'], '腾龙洞门票学生票\\n\\n': ['¥75起']}"
#  "{'恩施土司城门票成人票\\n\\n': ['¥42起'], '恩施土司城门票优待票\\n\\n': ['¥21起'], '恩施土司城门票亲子票(1大1小)\\n\\n': ['¥65起']}"
#  "{'恩施神农溪纤夫文化旅游区门票成人票\\n\\n': ['¥95起']}"
#  "{'龙麟宫门票成人票\\n\\n': ['¥42起'], '龙麟宫门票儿童票\\n\\n': ['¥21起'], '龙麟宫门票学生票\\n\\n': ['¥21起']}"
#  '具体收费情况以现场公示为主' nan '50元'
#  "{'恩施女儿城海洋公园门票成人票\\n\\n': ['¥49.9起'], '恩施女儿城海洋公园门票儿童票\\n\\n': ['¥58起'], '土家女儿城手机导游(不含门票)服务成人票\\n\\n': ['¥9起']}"
#  '位于矅天眼景区内，需先购买矅天眼景区门票方可进入' '包含于唐崖土司城遗址景区内，通用于唐崖土司城遗址景区门票。'
#  '位于彭家寨旅游景区内，需先购买彭家寨旅游景区门票方可入内。' '120元' '包含于狮子关景区内，通用于狮子关景区门票，狮子关景区门票120元']
# 恩施.csv - 建议游玩时间: ['建议游览时间：12小时 - 3天' '建议游览时间：3天 - 6天' '建议游览时间：12小时' '建议游览时间：2小时 - 5小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：2小时 - 4小时' '建议游览时间：2.5小时 - 3小时'
#  '建议游览时间：1小时 - 2小时' nan '建议游览时间：1小时' '建议游览时间：0.5小时 - 1小时' '建议游览时间：2小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：0.5小时' '建议游览时间：0.5小时 - 2小时' '建议游览时间：3小时']
# 文山.csv - 门票: ["{'普者黑柳叶小舟船票+观光车票成人票\\n\\n': ['¥230起'], '普者黑画舫船票+观光车票成人票\\n\\n': ['¥230起'], '普者黑水上浆板体验成人票\\n\\n': ['¥108起']}"
#  '具体收费情况以现场公示为主'
#  "{'坝美景区门票+观光车+游船套票成人票\\n\\n': ['¥180起'], '坝美景区电子导览服务大小同价\\n\\n': ['¥7起'], '昆明+抚仙湖+建水元阳+碧色寨普者黑+广南弥勒7日6晚私家团\\n\\n': ['¥3980起']}"
#  nan '免费' "{'浴仙湖手机导游服务成人票\\n\\n': ['¥6起']}" '具体收费情况以景区现场公示为主' '20元' '无'
#  '额外收费，具体费用请咨询景区']
# 文山.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' '建议游览时间：2小时' '建议游览时间：3天' nan '建议游览时间：3小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：1小时 - 2小时' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：4小时' '建议游览时间：1小时 - 3小时' '建议游览时间：1小时']
# 安顺.csv - 门票: ["{'黄果树瀑布夜游门票+观光车+双程扶梯票成人票\\n\\n': ['¥198起'], '黄果树瀑布夜游门票+观光车+双程扶梯票老人票\\n\\n': ['¥150起'], '黄果树瀑布日场门票(含观光车)+扶梯套票成人票\\n\\n': ['¥269起']}"
#  nan
#  "{'紫云格凸河风景名胜区门票+双程车票+全程船票+蜘蛛人表演票成人票\\n\\n': ['¥125起'], '格凸河穿洞风景名胜区门票+双程车票+全程船票+蜘蛛人攀岩票儿童票\\n\\n': ['¥77起'], '格凸河穿洞风景名胜区门票+双程车票+全程船票+蜘蛛人攀岩票老人票\\n\\n': ['¥100起']}"
#  '具体收费情况以现场公示为主'
#  "{'天星桥电子导览服务大小同价\\n\\n': ['¥6起'], '纯玩+夜宿苗寨 黄果树瀑布+西江千户苗寨+小七孔三日游\\n\\n': ['¥689起'], '黄果树瀑布、荔波小七孔、西江千户苗寨等纯玩3日跟团游\\n\\n': ['¥478起']}"
#  "{'纯玩+夜宿苗寨 黄果树瀑布+西江千户苗寨+小七孔三日游\\n\\n': ['¥689起'], '黄果树瀑布、荔波小七孔、西江千户苗寨等纯玩3日跟团游\\n\\n': ['¥478起'], '【千人好评】贵州黄果树瀑布+天星桥+陡坡塘瀑布纯玩一日游 可选一环接早\\n\\n': ['¥109起']}"
#  "{'天龙屯堡电子导览服务大小同价\\n\\n': ['¥8起'], '贵州安顺栖野旧州露营地【拎包入住轻奢露营体验】\\n\\n': ['¥480起']}"
#  '40元' '免费' '60元'
#  "{'花江大峡谷门票成人票\\n\\n': ['¥30起'], '花江大峡谷门票+游船票成人票\\n\\n': ['¥108起'], '花江大峡谷电子导览服务大小同价\\n\\n': ['¥5起']}"
#  "{'【千人好评】贵州黄果树瀑布+天星桥+陡坡塘瀑布纯玩一日游 可选一环接早\\n\\n': ['¥109起'], '纯玩-贵州黄果树瀑布+天星桥+陡坡塘一日游 赠送环保车含中餐\\n\\n': ['¥298起'], '优选·贵州黄果树瀑布一日游·承诺真纯玩│陡坡塘瀑布+天星桥\\n\\n': ['¥258起']}"
#  "{'夜郎洞门票成人票\\n\\n': ['¥85起'], '夜郎洞电子导览服务大小同价\\n\\n': ['¥10起'], '贵州安顺栖野旧州露营地【拎包入住轻奢露营体验】\\n\\n': ['¥480起']}"
#  '90元' '70元' '园内游玩项目具体收费情况以现场公示为主。' '包含在黄果树景区门票内'
#  "{'岚山景区门票儿童票\\n\\n': ['¥20起']}" '收费']
# 安顺.csv - 建议游玩时间: ['建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 4小时' nan '建议游览时间：3小时 - 4小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：3小时' '建议游览时间：1小时 - 2小时' '建议游览时间：2小时'
#  '建议游览时间：0.5小时' '建议游览时间：1小时' '建议游览时间：0.5小时 - 2小时' '建议游览时间：3小时 - 5小时'
#  '建议游览时间：0.5小时 - 1小时']
# 龙岩.csv - 门票: ["{'福建土楼客家民俗文化村（洪坑土楼）门票成人票\\n\\n': ['¥85起'], '福建土楼客家民俗文化村（洪坑土楼）门票儿童票\\n\\n': ['¥45起'], '福建土楼客家民俗文化村（洪坑土楼）门票学生票\\n\\n': ['¥32.5起']}"
#  '具体收费情况以现场公示为主'
#  "{'冠豸山门票+竹安寨+缆车+景交车(不含游湖)票成人票\\n\\n': ['¥150起'], '赖源溶洞门票成人票\\n\\n': ['¥76起'], '培田古民居门票成人票\\n\\n': ['¥44起']}"
#  "{'培田古民居门票成人票\\n\\n': ['¥44起'], '培田古民居古村落门票成人票\\n\\n': ['¥44.9起'], '培田古民居手机智能导游讲解服务大小同价\\n\\n': ['¥6起']}"
#  nan "{'漳平永福樱花园+万亩茶园包车一日游【茶山赏浪漫樱花】\\n\\n': ['¥680起']}"
#  "{'初溪土楼群门票成人票\\n\\n': ['¥60起'], '永定土楼群（福建客家土楼）初溪古村落门票成人票\\n\\n': ['¥60起'], '永定土楼群（福建客家土楼）初溪古村落门票儿童票\\n\\n': ['¥32.5起']}"
#  "{'永福台品樱花茶园花卉展销中心金兴园艺票大小同价\\n\\n': ['¥10起'], '永福台品樱花茶园网红小火车票大小同价\\n\\n': ['¥28起'], '永福台品樱花茶园樱花大火车票大小同价\\n\\n': ['¥28起']}"
#  "{'龙岩森林水乡景区门票成人票\\n\\n': ['¥68起'], '龙岩森林水乡景区森林水乡门票成人票\\n\\n': ['¥68起'], '龙岩森林水乡九溪庐漂流观光门票+天际线滑车+步步惊心+丛林飞跃B线+射箭+小火车套票成人票\\n\\n': ['¥168起']}"
#  "{'龙岩苍听野奢营地【拎包入住轻奢露营体验/自带装备不过夜露营】\\n\\n': ['¥60起']}" '90元' '免费'
#  "{'永定土楼福建土楼王门票成人票\\n\\n': ['¥48起'], '永定土楼群（福建客家土楼）福建土楼王门票儿童票\\n\\n': ['¥25起'], '永定土楼福建土楼王门票学生票\\n\\n': ['¥25起']}"
#  "{'【独立包车】厦门-龙岩梅花山中国虎园+古田会议一日游 专车1对1VIP服务出发时间自由多种车型可选\\n\\n': ['¥1388起']}"
#  "{'梁野山门票成人票\\n\\n': ['¥53起'], '梁野山门票大小同价\\n\\n': ['¥5起'], '梁野山门票老人票\\n\\n': ['¥27起']}"
#  '62元' '高北村土楼群门票为50元/人，包括承启楼、世泽楼与五云楼等代表建筑。' '30元'
#  "{'【厦门出发】永定高北土楼王一日游（头等舱云水谣土楼双景可选）\\n\\n': ['¥118起'], '{走高速}永定高北土楼、土楼王承启楼、五云楼、乔福楼一日游\\n\\n': ['¥168起'], '含接送/午餐/讲解 永定高北土楼王承启楼土楼一日游 纯玩团\\n\\n': ['¥128起']}"
#  '2元' '10元'
#  "{'龙岩东肖森林公园门票成人票\\n\\n': ['¥24起'], '龙岩东肖森林公园门票优待票\\n\\n': ['¥15起']}"]
# 龙岩.csv - 建议游玩时间: ['建议游览时间：1小时 - 2小时' '建议游览时间：2小时 - 3小时' '建议游览时间：3天' '建议游览时间：1天' nan
#  '建议游览时间：12小时 - 3天' '建议游览时间：1小时' '建议游览时间：2小时' '建议游览时间：3小时 - 4小时'
#  '建议游览时间：4小时 - 6小时' '建议游览时间：4小时' '建议游览时间：0.8小时 - 1.5小时']
# 商丘.csv - 门票: [nan '景区联票100元' '20元' '10元' '具体收费情况以现场公示为主' '免费'
#  "{'芒砀山刘邦斩蛇处门票优待票\\n\\n': ['¥15起'], '芒砀山刘邦斩蛇处门票成人票\\n\\n': ['¥30起'], '芒砀山旅游区电子讲解票大小同价\\n\\n': ['¥0.5起']}"
#  '5元' '15元'
#  "{'僖山景区门票成人票\\n\\n': ['¥30起'], '僖山景区门票优待票\\n\\n': ['¥15起'], '汉梁王陵门票+僖山景区门票成人票\\n\\n': ['¥85起']}"
#  '收费']
# 商丘.csv - 建议游玩时间: [nan '建议游览时间：1小时' '建议游览时间：1小时 - 2小时' '建议游览时间：0.5小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：0.2小时 - 0.5小时' '建议游览时间：3天' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：2小时' '建议游览时间：3小时']
# 潜江.csv - 门票: [nan '具体收费情况以现场公示为主' '免费' '景区内所有观光旅游项目' '凭有效证件登记参观，团体需预约。']
# 潜江.csv - 建议游玩时间: [nan '建议游览时间：4小时 - 5小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时 - 2小时' '建议游览时间：1小时'
#  '建议游览时间：1小时 - 3小时']
# 广州.csv - 门票: ["{'长隆野生动物世界一日门票亲子票(1大1小)\\n\\n': ['¥505起'], '长隆野生动物世界一日门票女士票\\n\\n': ['¥345起'], '长隆野生动物世界一日门票成人票\\n\\n': ['¥295起']}"
#  "{'广州塔433米白云星空观光票成人票\\n\\n': ['¥148起'], '广州塔433米白云星空观光票儿童票\\n\\n': ['¥75起'], '广州塔433米白云星空观光票优待票\\n\\n': ['¥75起']}"
#  "{'沙面艺术中心L.C美术馆门票大小同价\\n\\n': ['¥67.8起'], '沙面艺术中心L.C美术馆门票三人票\\n\\n': ['¥127.6起'], '沙面艺术中心L.C美术馆门票双人票\\n\\n': ['¥97.6起']}"
#  "{'北京路步行街无线耳麦2小时人工讲解服务大小同价\\n\\n': ['¥48起'], '广州一日游：陈家祠+广州塔+沙面+石室圣心大教堂+永庆坊+海心桥一日游\\n\\n': ['¥168起'], '广州白云山+陈家祠+黄埔军校+花城广场+二沙岛一日游/含景交/品尝岭南风情宴/广场休闲游/打卡小蛮腰\\n\\n': ['¥288起']}"
#  "{'千泷沟大瀑布（含售票处-半山往返观光车）门票成人票\\n\\n': ['¥58起'], '千泷沟大瀑布（含售票处-半山往返观光车）门票儿童票\\n\\n': ['¥28起'], '千泷沟大瀑布（含售票处-半山往返观光车）门票老人票\\n\\n': ['¥28起']}"
#  "{'陈家祠手机智能语音导览服务成人票\\n\\n': ['¥0.1起'], '陈家祠私享人工讲解服务大小同价\\n\\n': ['¥350起'], '陈家祠门票+人工讲解服务成人票\\n\\n': ['¥68起']}"
#  "{'广州长隆欢乐世界门票女士票\\n\\n': ['¥235起'], '广州长隆欢乐世界门票成人票\\n\\n': ['¥230起'], '广州长隆欢乐世界门票儿童票\\n\\n': ['¥175起']}"
#  '具体收费情况以现场公示为主'
#  "{'宝墨园门票成人票\\n\\n': ['¥45.8起'], '宝墨园门票优待票\\n\\n': ['¥27起'], '宝墨园门票双人票\\n\\n': ['¥96起']}"
#  "{'南沙天后宫门票成人票\\n\\n': ['¥18起'], '南沙天后宫门票优待票\\n\\n': ['¥10起'], '南沙天后宫门票双人票\\n\\n': ['¥36起']}"
#  "{'海珠湿地门票成人票\\n\\n': ['¥20起'], '海珠国家湿地公园电子导览服务大小同价\\n\\n': ['¥9起'], '广州帽林露营地过夜露营体验【拎包入住轻奢露营地】\\n\\n': ['¥60起']}"
#  "{'广东省博物馆手机智能语音讲解服务大小同价\\n\\n': ['¥0.9起'], '广东省博物馆门票+电子导览票大小同价\\n\\n': ['¥55起'], '2-6人大咖小团-广东省博物馆半日游【门票+人工讲解团+大小同价】\\n\\n': ['¥198起']}"
#  "{'广州塔+白云山+沙面+永庆坊+陈家祠+珠江夜游一日游\\n\\n': ['¥258起']}" nan
#  "{'白水寨风景名胜区门票成人票\\n\\n': ['¥48起'], '白水寨风景名胜区门票优待票\\n\\n': ['¥30起'], '白水寨风景名胜区年卡成人票\\n\\n': ['¥159起']}"
#  "{'大夫山森林公园手机导游(不含门票)讲解、路线推荐服务大小同价\\n\\n': ['¥9起']}"
#  "{'白云飞索门票大小同价\\n\\n': ['¥168起'], '白云飞索门票学生票\\n\\n': ['¥168起'], '白云飞索门票双人票\\n\\n': ['¥399起']}"
#  '温室票另收费50元。'
#  '票价：2元，支持羊城通设有自助购票机，可微信、支付宝凭广州、佛山老年人优待证以及广州市规定可以免费乘坐公共交通的人群，凭相关证件可免费乘车。另，试乘纪念券2元1张，每人一票，可当天无限次乘坐。'
#  '免费'
#  "{'正佳极地海洋世界门票成人票\\n\\n': ['¥202.3起'], '广州正佳极地海洋世界门票大小同价\\n\\n': ['¥130起'], '正佳极地海洋世界门票儿童票\\n\\n': ['¥130起']}"
#  "{'广州经典纯玩1日游、广州塔外观+黄埔军校+陈家祠+白云山+沙面+越秀公园+含午餐、可选珠江夜游、\\n\\n': ['¥268起'], '广州一日游：广州塔+白云山+陈家祠+沙面+越秀公园+花城广场【纯玩团天天出发】\\n\\n': ['¥98起'], '广州7大景点纯玩一日游【上门接/无购物/无自费/土著导游】\\n\\n': ['¥198起']}"
#  "{'岭南印象园南国奇遇夜票成人票\\n\\n': ['¥49.3起'], '岭南印象园南国奇遇夜票优待票\\n\\n': ['¥39起'], '岭南印象园门票成人票\\n\\n': ['¥47.8起']}"
#  "{'世间香境·七溪地景区观光票(含香囊定制)优待票\\n\\n': ['¥68起'], '世间香境·七溪地景区观光票(含香囊定制)成人票\\n\\n': ['¥98起'], '世间香境·七溪地景区套票(含全部体验活动)优待票\\n\\n': ['¥138起']}"
#  '40元'
#  "{'沙湾古镇展馆通票成人票\\n\\n': ['¥30起'], '沙湾古镇展馆通票优待票\\n\\n': ['¥20起'], '沙湾古镇电子导览服务大小同价\\n\\n': ['¥9起']}"
#  "{'广州动物园门票+奥咖HOKA光影剧场门票成人票\\n\\n': ['¥46起'], '广州动物园电子导览服务大小同价\\n\\n': ['¥1.9起'], '广州动物园门票+手机导览套餐成人票\\n\\n': ['¥38起']}"
#  "{'石门国家森林公园驴迹电子导览（不含门票）票成人票\\n\\n': ['¥9起'], '小车上门接送、从化石门国家森林公园1天游、高山天池花海、玫瑰园、赏红枫叶等、一单一团独享专属旅行\\n\\n': ['¥328起'], '广州从化新航线越野俱乐部【越野车驾驶/真人cs/皮划艇体验】\\n\\n': ['¥88起']}"
#  "{'天适樱花悠乐园樱花节门票成人票\\n\\n': ['¥34.5起'], '天适樱花悠乐园樱花节门票优待票\\n\\n': ['¥34.5起'], '天适樱花悠乐园樱花节门票亲子票(1大1小)\\n\\n': ['¥68起']}"
#  "{'越秀公园景区手机电子导游(不含门票)  票大小同价\\n\\n': ['¥0.2起'], '广州经典纯玩跟团一日游（9大景点2个正餐全程导服旅游大巴）\\n\\n': ['¥258起'], '广州经典纯玩1日游、广州塔外观+黄埔军校+陈家祠+白云山+沙面+越秀公园+含午餐、可选珠江夜游、\\n\\n': ['¥268起']}"
#  "{'西汉南越王博物馆+中山纪念堂+越秀山+五羊石雕门票+导游讲解服务\\n\\n': ['¥138起'], '西汉南越王博物馆+中山纪念堂+五羊石雕优待票\\n\\n': ['¥118起'], '中山纪念堂门票+导游讲解服务\\n\\n': ['¥88起']}"
#  "{'太古仓游艇包船体验大小同价\\n\\n': ['¥5888起']}"
#  "{'流溪河国家森林公园门票成人票\\n\\n': ['¥32起'], '流溪河国家森林公园门票优待票\\n\\n': ['¥20起'], '五指山三桠塘幽谷门票成人票\\n\\n': ['¥32起']}"
#  "{'百万葵园门票成人票\\n\\n': ['¥38起'], '百万葵园门票儿童票\\n\\n': ['¥38起'], '百万葵园门票双人票\\n\\n': ['¥82.7起']}"
#  '130元'
#  "{'广州白云区山点水越野俱乐部/越野车驾驶体验/真实丛林赛道\\n\\n': ['¥188起'], '广州帽林露营地过夜露营体验【拎包入住轻奢露营地】\\n\\n': ['¥60起']}"
#  "{'飞越丛林探险乐园儿童蜘蛛网票儿童票\\n\\n': ['¥29.9起'], '飞越丛林探险乐园金线票大小同价\\n\\n': ['¥96.2起'], '飞越丛林探险乐园橙线票大小同价\\n\\n': ['¥75起']}"
#  "{'南粤苑门票成人票\\n\\n': ['¥41.5起'], '南粤苑门票优待票\\n\\n': ['¥25起'], '宝墨园门票+南粤苑门票成人票\\n\\n': ['¥75起']}"
#  '游船需收费'
#  "{'成都融创堇悦酒店2晚连住+双人自助早餐+双人成都融创乐园+双人熊猫谷门票+双人都江堰门票\\n\\n': ['¥1799起']}"
#  "{'珠江夜游天字码头(广州财富号)游船票成人票\\n\\n': ['¥88起'], '珠江夜游天字码头(广州财富号)游船票双人票\\n\\n': ['¥175起'], '珠江夜游天字码头（广发证券号）游船票成人票\\n\\n': ['¥88起']}"
#  '65元'
#  "{' 石头记矿物园门票成人票\\n\\n': ['¥54.8起'], ' 石头记矿物园门票大小同价\\n\\n': ['¥55起'], ' 石头记矿物园门票儿童票\\n\\n': ['¥30起']}"
#  "{'石室圣心大教堂电子导览票大小同价\\n\\n': ['¥6起'], '广州一日游：陈家祠+广州塔+沙面+石室圣心大教堂+永庆坊+海心桥一日游\\n\\n': ['¥168起']}"
#  "{'南越王博物馆+人工讲解服务成人票\\n\\n': ['¥68起'], '南越王博物馆+人工讲解服务老人票\\n\\n': ['¥60起'], '南越王博物馆+人工讲解服务儿童票\\n\\n': ['¥60起']}"
#  "{'余荫山房门票成人票\\n\\n': ['¥14起'], '余荫山房门票优待票\\n\\n': ['¥9起'], '余荫山房门票双人票\\n\\n': ['¥28起']}"
#  "{'黄埔军校旧址纪念馆（不含门票）手机电子导游票大小同价\\n\\n': ['¥4.8起'], '广州塔+白云山+沙面+永庆坊+陈家祠+珠江夜游一日游\\n\\n': ['¥258起'], '广州经典纯玩1日游、广州塔外观+黄埔军校+陈家祠+白云山+沙面+越秀公园+含午餐、可选珠江夜游、\\n\\n': ['¥268起']}"
#  "{'广州荔枝湾游船二选一码头任选船票(文塔/永庆坊)成人票\\n\\n': ['¥55起'], '广州荔枝湾游船二选一码头任选船票(文塔/永庆坊)儿童票\\n\\n': ['¥30起'], '广州荔枝湾游船二选一码头任选船票(文塔/永庆坊)老人票\\n\\n': ['¥40起']}"
#  "{'小洲村手机导游(不含门票)讲解、路线推荐服务大小同价\\n\\n': ['¥7起']}" '观众凭有效证件入场参观。' '80元'
#  "{'广州博物馆VIP包团讲解服务(由旅行社提供)大小同价\\n\\n': ['¥299起'], '【精讲广州】+广州博物馆（即越秀公园镇海楼）趣味讲解1.5小时\\n\\n': ['¥68起']}"
#  "{'天河公园电子讲解票大小同价\\n\\n': ['¥8起'], '【酒店套餐】广州黄埔君澜酒店1晚+双早+双人下午茶+SPA抵用券+迷你吧\\n\\n': ['¥709起']}"
#  "{'流花湖公园电子导览服务大小同价\\n\\n': ['¥7起']}"
#  "{'南沙湿地观光票成人票\\n\\n': ['¥38起'], '南沙湿地观光票优待票\\n\\n': ['¥20起'], '南沙湿地观光票亲子票(1大1小)\\n\\n': ['¥57起']}"
#  '包含在白云山风景区的门票内']
# 广州.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' '建议游览时间：2小时 - 4小时' '建议游览时间：3小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：0.5小时 - 2小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：3小时 - 3.4小时' '建议游览时间：1小时' '建议游览时间：12小时' '建议游览时间：1小时 - 2小时' nan
#  '建议游览时间：12小时 - 6天' '建议游览时间：4小时 - 6小时' '建议游览时间：0.5小时' '建议游览时间：3小时 - 5小时'
#  '建议游览时间：3天' '建议游览时间：2小时 - 5小时' '建议游览时间：2小时' '建议游览时间：5小时 - 6小时'
#  '建议游览时间：3小时 - 6小时' '建议游览时间：1小时 - 3小时' '建议游览时间：10小时 - 15小时'
#  '建议游览时间：0.3小时 - 0.5小时']
# 汕尾.csv - 门票: ["{'红海湾旅游区门票优待票\\n\\n': ['¥8起'], '汕尾红海湾电子导览服务大小同价\\n\\n': ['¥6起'], '红海湾旅游区淡水冲水服务大小同价\\n\\n': ['¥14起']}"
#  '具体收费情况以现场公示为主' "{'导览服务成人票\\n\\n': ['¥8起']}" nan '免费']
# 汕尾.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' '建议游览时间：3天' '建议游览时间：1小时 - 2小时' '建议游览时间：1小时 - 3小时' nan
#  '建议游览时间：1小时' '建议游览时间：0.5小时 - 1小时' '建议游览时间：2小时 - 3小时' '建议游览时间：12小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：5小时' '建议游览时间：3小时 - 4小时' '建议游览时间：6天']
# 乐山.csv - 门票: ["{'乐山大佛门票成人票\\n\\n': ['¥80起'], '乐山大佛门票儿童票\\n\\n': ['¥40起'], '乐山大佛门票老人票\\n\\n': ['¥40起']}"
#  '具体收费情况以现场公示为主'
#  "{'峨眉山门票+全山往返观光车+金顶往返索道成人票\\n\\n': ['¥370起'], '峨眉山门票+全山往返观光车+金顶往返索道儿童票\\n\\n': ['¥195起'], '峨眉山门票+全山往返观光车+金顶往返索道学生票\\n\\n': ['¥290起']}"
#  "{'黑竹沟门票成人票\\n\\n': ['¥48起'], '黑竹沟门票儿童票\\n\\n': ['¥25起'], '黑竹沟门票学生票\\n\\n': ['¥25起']}"
#  nan
#  "{'峨眉山门票成人票\\n\\n': ['¥160起'], '峨眉山门票儿童票\\n\\n': ['¥80起'], '峨眉山门票\\n\\n': ['¥80起']}"
#  '免费' '包含于峨眉山景区内，通用峨眉山景区门票。' '包含在峨眉山景区的门票内' '包含在峨眉山景区门票内'
#  "{'犍为文庙大门票优待票\\n\\n': ['¥15起'], '犍为文庙电子导览服务大小同价\\n\\n': ['¥9起']}"
#  '包含在乐山大佛景区门票内'
#  "{'沐川竹海门票成人票\\n\\n': ['¥39起'], '沐川竹海电子导览服务大小同价\\n\\n': ['¥6起']}"
#  "{'轻松欢乐游-乐山大佛+黄龙溪1日游；真纯玩0购物；市区三环内早接\\n\\n': ['¥188起'], '【玩转峨眉】乐山大佛+峨眉山/黄龙溪古镇一日游丨观乐山大佛全景丨纯玩无购物丨特色餐食\\n\\n': ['¥230起'], '【漫游乐山】乐山大佛一日游丨可选黄龙溪/峨眉山/熊猫基地/10点出发丨专业导游讲解丨轻松亲子游爸妈游\\n\\n': ['¥188起']}"
#  '成人：40元 儿童：20元' '包括在峨眉山门票内。' '20元' '39元' '首道大门票收费情况请咨询景区']
#  "{'大连三寰牧场门票大小同价\\n\\n': ['¥29.9起'], '三寰牧场门票双人票\\n\\n': ['¥99起'], '大连三寰牧场+监狱旧址+潜艇博物馆+讲解+帆船出海服务成人票\\n\\n': ['¥189起']}"
#  "{'华酝牡丹园日场门票成人票\\n\\n': ['¥23.8起']}" '公园及寺庙皆可免费进入。' '免费'
#  "{'英歌石植物园门票成人票\\n\\n': ['¥30起'], '大连英歌石植物园电子导览服务大小同价\\n\\n': ['¥6起']}"
#  '免费。'
#  "{'大连现代博物馆电子导游票大小同价\\n\\n': ['¥6起'], '大连环城海滨一日游轻奢1-6小团可选一单一团、棒槌岛帆船出海\\n\\n': ['¥268起'], '大连棒棰岛+滨海路+威尼斯水城+帆船出海一日游\\n\\n': ['¥106起']}"
#  "{'大连贝壳博物馆门票成人票\\n\\n': ['¥65起'], '大连贝壳博物馆门票学生票\\n\\n': ['¥50起'], '大连贝壳博物馆门票老人票\\n\\n': ['¥50起']}"
#  "{'白玉山景区门票成人票\\n\\n': ['¥36起'], '白玉山景区门票优待票\\n\\n': ['¥20起'], '白玉山自动导游5个讲解服务大小同价\\n\\n': ['¥0.5起']}"
#  "{'闯关东影视基地+日俄监狱旧址博物馆门票+旅顺博物馆+旅顺潜艇博物馆+导游讲解服务成人票\\n\\n': ['¥188起'], '闯关东影视基地+日俄监狱旧址博物馆门票+旅顺博物馆+旅顺潜艇博物馆+导游讲解服务儿童票\\n\\n': ['¥90起'], '大连三寰牧场+监狱旧址+潜艇博物馆+讲解+帆船出海服务成人票\\n\\n': ['¥189起']}"
#  "{'大连自然博物馆手机导游(不含门票)手绘地图、讲解、服务成人票\\n\\n': ['¥1.9起']}"
#  "{'大连市区包车游|家庭出游|棒棰岛-圣亚海洋世界-滨海路\\n\\n': ['¥368起']}" '具体收费情况以景区现场公示为主。'
#  "{'劳动公园富斯特索滑道（上行索道+下行滑道）票成人票\\n\\n': ['¥78起'], '劳动公园富斯特索滑道（上行索道+下行滑道）票儿童票\\n\\n': ['¥48起']}"
#  "{'大连一日游【豪华10人小团】纯玩棒棰岛+帆船出海+威尼斯水城\\n\\n': ['¥108起'], '轻奢小团 慢游大连 在慢时光中寻味百年大连的浪漫\\n\\n': ['¥368起']}"
#  "{'大连海滨旅顺口门票成人票\\n\\n': ['¥30起'], '大连海滨旅顺口门票优待票\\n\\n': ['¥15起']}"
#  "{'大连一日游【豪华10人小团】纯玩棒棰岛+帆船出海+威尼斯水城\\n\\n': ['¥108起'], '大连棒棰岛+滨海路+威尼斯水城+帆船出海一日游\\n\\n': ['¥106起']}"
#  "{'大连铭湖温泉会馆门票成人票\\n\\n': ['¥103起'], '大连铭湖国际温泉滑雪度假区温泉门票+自助午餐票成人票\\n\\n': ['¥149起'], '【酒店套餐】大连铭湖国际温泉滑雪度假村酒店1晚+双人温泉门票+次日早餐\\n\\n': ['¥588起']}"
#  '建议游览时间：3小时 - 5小时' '建议游览时间：2小时 - 4小时' nan '建议游览时间：3小时 - 4小时' '建议游览时间：2小时'
#  '建议游览时间：4小时 - 1天' '建议游览时间：4小时 - 6小时' '建议游览时间：2小时 - 6小时'
#  '建议游览时间：0.5小时 - 1小时' '建议游览时间：0.5小时' '建议游览时间：12小时 - 3天' '建议游览时间：5小时'
#  '建议游览时间：12小时' '建议游览时间：3小时']
# 厦门.csv - 门票: ["{'厦门乘风帆船出海帆船体验券大小同价\\n\\n': ['¥60起'], '厦门胡里山炮台门票成人票\\n\\n': ['¥23起'], '厦门胡里山炮台门票学生票\\n\\n': ['¥12起']}"
#  "{'故宫鼓浪屿外国文物馆门票成人票\\n\\n': ['¥50起'], '故宫鼓浪屿外国文物馆门票学生票\\n\\n': ['¥25起'], '番婆楼门票成人票\\n\\n': ['¥86.4起']}"
#  "{'厦门乘风帆船出海帆船体验券大小同价\\n\\n': ['¥60起'], '晟达海游艇俱乐部帆船出海体验成人票\\n\\n': ['¥55起'], '晟达海游艇俱乐部帆船出海体验优待票\\n\\n': ['¥49起']}"
#  "{'时空魔方门票成人票\\n\\n': ['¥62起'], '时空魔方门票儿童票\\n\\n': ['¥43起'], '时空魔方门票亲子票(1大1小)\\n\\n': ['¥106起']}"
#  '参观人员从大南校门、群贤校门进校，游客进入厦门大学需提前至“厦门大学访客预约系统”微信号进行预约。'
#  "{'厦门胡里山炮台门票成人票\\n\\n': ['¥23起'], '厦门胡里山炮台门票学生票\\n\\n': ['¥12起'], '厦门胡里山炮台门票老人票\\n\\n': ['¥10起']}"
#  nan
#  "{'厦门园林植物园门票成人票\\n\\n': ['¥30起'], '厦门园林植物园门票优待票\\n\\n': ['¥15起'], '厦门园林植物园厦门旅游年卡大小同价\\n\\n': ['¥195起']}"
#  "{'椰风寨海洋科普乐园门票\\n\\n': ['¥79起'], '【精品小团】厦门植物园+环岛路+曾厝垵+椰风寨海洋乐园一日游\\n\\n': ['¥488起'], '【酒店套餐】长泰半月山温泉酒店2大2小早餐+室内独立泡池+温泉+迎宾水果\\n\\n': ['¥799起']}"
#  "{'世茂云上厦门观光厅55F+58F爱情天台（夜场）门票成人票\\n\\n': ['¥105起'], '世茂云上厦门观光厅55F+58F爱情天台（夜场）门票双人票\\n\\n': ['¥207.9起'], '云上厦门观光厅55F+58F爱情天台门票成人票\\n\\n': ['¥148起']}"
#  "{'集美学村人工讲解服务大小同价\\n\\n': ['¥299起'], '集美学村电子导览服务大小同价\\n\\n': ['¥0.3起'], '集美学村中高级私享人工讲解服务票大小同价\\n\\n': ['¥439起']}"
#  "{'钟鼓索道（往返）成人票\\n\\n': ['¥80起'], '钟鼓索道钟鼓山景区驴迹电子导览(不含门票)体验大小同价\\n\\n': ['¥9起'], 'VIP小团厦门市区+网红植物园+钟鼓索道+曾厝垵美食街+灵玲马戏城一日游\\n\\n': ['¥688起']}"
#  "{'厦门日光岩门票成人票\\n\\n': ['¥50起'], '日光岩门票儿童票\\n\\n': ['¥25起'], '日光岩门票学生票\\n\\n': ['¥25起']}"
#  "{'厦门市区纯玩一日游|南普陀+厦大外观+曾厝垵+沙坡尾+环岛路\\n\\n': ['¥299起'], '【15人小团】厦门滩涂赶海+帆船出海一日游丨渔民真实赶海体验+海鲜大咖锅+帆船出海邂逅白海豚\\n\\n': ['¥128起'], '12人精品小团丨厦门鼓浪屿+南普陀寺+曾厝垵+环岛路2天1晚\\n\\n': ['¥558起']}"
#  "{'【酒店套餐】长泰半月山温泉酒店2大2小早餐+室内独立泡池+温泉+迎宾水果\\n\\n': ['¥799起'], '厦门+曾厝垵+环岛路+赶海+集美学村+园博苑水上月光环 | 一日游（免费接送+含餐）\\n\\n': ['¥139起']}"
#  "{'【厦门一日游】海上小火车+曾厝垵+集美学村+滩涂赶海+网红坡看夕阳（含餐、接送、纯玩）\\n\\n': ['¥139起']}"
#  '具体收费情况以现场公示为主'
#  "{'厦门海底世界门票成人票\\n\\n': ['¥107起'], '厦门海底世界门票儿童票\\n\\n': ['¥58起'], '厦门海底世界门票双人票\\n\\n': ['¥198起']}"
#  "{'厦门科技馆主展厅票+儿童馆票+飞越影院票成人票\\n\\n': ['¥99起'], '厦门科技馆主展厅票+儿童馆票+飞越影院票学生票\\n\\n': ['¥80起'], '厦门科技馆主展厅票+儿童馆票+飞越影院票优待票\\n\\n': ['¥79起']}"
#  '参观免费，其他消费项目另收费。'
#  "{'菽庄花园门票成人票\\n\\n': ['¥30起'], '菽庄花园门票儿童票\\n\\n': ['¥5起'], '菽庄花园门票学生票\\n\\n': ['¥15起']}"
#  "{'【厦门夜游、自由行】豪华游船+海上会客厅+花式调酒表演 | 一日游\\n\\n': ['¥258起']}" '免费'
#  "{'晟达海游艇俱乐部帆船出海体验成人票\\n\\n': ['¥55起'], '晟达海游艇俱乐部帆船出海体验优待票\\n\\n': ['¥49起'], '晟达海游艇俱乐部帆船出海体验团队票\\n\\n': ['¥1380起']}"
#  "{'风琴博物馆门票成人票\\n\\n': ['¥15起'], '风琴博物馆门票儿童票\\n\\n': ['¥7.5起'], '风琴博物馆门票学生票\\n\\n': ['¥7.5起']}"
#  '景区免费进入，景区内梦幻世界乐园、车技馆等另收费，详情请电话咨询景区。' '68元'
#  "{'海天堂构门票成人票\\n\\n': ['¥74.5起'], '海天堂构门票儿童票\\n\\n': ['¥45起'], '海天堂构门票老人票\\n\\n': ['¥45起']}"
#  "{'厦门鼓浪屿+万国建筑群一日游|可订含菽庄花园/旅拍套餐\\n\\n': ['¥129起'], '厦门鼓浪屿+万国建筑博览+菽庄花园一日游【上门接含船票门票午餐 可选日光岩】\\n\\n': ['¥311起'], '厦门+鼓浪屿5日半自助游（全天接送机+五星豪华海景酒店住宿+胡里山炮台+菽庄花园+厦门大学）\\n\\n': ['¥1333起']}"
#  "{'皓月园门票成人票\\n\\n': ['¥10起'], '皓月园门票儿童票\\n\\n': ['¥5起'], '皓月园门票学生票\\n\\n': ['¥5起']}"
#  '具体收费情况以景区现场公示为主。' "{'嘉庚公园电子导览服务大小同价\\n\\n': ['¥0.5起']}"
#  '建议游览时间：0.2小时 - 0.3小时' '建议游览时间：0.5小时' '建议游览时间：3小时 - 5小时'
#  '建议游览时间：1小时 - 5小时' '建议游览时间：0.1小时 - 0.2小时' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：1.5小时' '建议游览时间：1.2小时' '建议游览时间：3小时']
# 双河.csv - 门票: [nan]
# 双河.csv - 建议游玩时间: [nan]
# 博尔塔拉.csv - 门票: ["{'赛里木湖湖自驾游赛湖一日票成人票\\n\\n': ['¥144.6起'], '赛里木湖自驾游赛湖二日票成人票\\n\\n': ['¥189.6起'], '赛里木湖电子导览服务大小同价\\n\\n': ['¥9起']}"
#  "{'怪石峪风景区门票成人票\\n\\n': ['¥48起'], '怪石峪风景区门票优待票\\n\\n': ['¥24起'], '怪石峪风景区电子导览门票大小同价\\n\\n': ['¥6起']}"
#  '免费' nan '具体收费情况以现场公示为主' '需购买赛里木湖景区大门票' '需购买景区大门票']
# 博尔塔拉.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' '建议游览时间：3小时 - 4小时' nan '建议游览时间：3小时' '建议游览时间：6天'
#  '建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 3小时' '建议游览时间：2小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：12小时']
# 五家渠.csv - 门票: ['具体收费情况以现场公示为主' nan]
# 五家渠.csv - 建议游玩时间: ['建议游览时间：2小时 - 4小时' nan '建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 3小时']
# 屯昌.csv - 门票: ['具体收费情况以现场公示为主' nan]
# 屯昌.csv - 建议游玩时间: [nan '建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时' '建议游览时间：3天'
#  '建议游览时间：3小时' '建议游览时间：2小时']
# 宜春.csv - 门票: [nan
#  "{'三爪仑虎啸峡门票成人票\\n\\n': ['¥18起'], '三爪仑白水洞门票成人票\\n\\n': ['¥59起'], '三爪仑观音岩门票成人票\\n\\n': ['¥58起']}"
#  '免费政策：\n 儿童身高1.3米以下免费。'
#  "{'明月山天沐温泉度假村山谷温泉门票成人票\\n\\n': ['¥129起'], '明月山天沐温泉度假村山谷温泉门票儿童票\\n\\n': ['¥80起'], '明月山天沐温泉度假村山谷温泉门票双人票\\n\\n': ['¥336起']}"
#  "{'阁皂山风景名胜区门票成人票\\n\\n': ['¥19起'], '阁皂山电子导览服务大小同价\\n\\n': ['¥9起']}" '免费'
#  '具体收费情况以现场公示为主' '128元'
#  "{'中华传统文化园体验票成人票\\n\\n': ['¥55起'], '中华传统文化园体验票儿童票\\n\\n': ['¥25起']}"
#  '免大门票，园内项目单收费' '80元'
#  "{'三爪仑鹤栖谷景区门票成人票\\n\\n': ['¥18起'], '三爪仑鹤栖谷景区玻璃漂流票成人票\\n\\n': ['¥88起'], '三爪仑鹤栖谷景区门票+高空玻璃漂流/高空玻璃飞车+飞天魔毯+天空悬廊套票成人票\\n\\n': ['¥80起']}"
#  "{'百峰岭景区电子导览服务大小同价\\n\\n': ['¥10起'], '百峰岭景区门票+观光车优待票\\n\\n': ['¥40起'], '百峰岭景区门票+观光车成人票\\n\\n': ['¥71起']}"
#  "{'铜鼓东浒景区门票成人票\\n\\n': ['¥68起'], '铜鼓东浒景区通票成人票\\n\\n': ['¥108起'], '【酒店套餐】铜鼓汤里森林温泉度假区2天1晚+双早+双人温泉\\n\\n': ['¥510起']}"
#  "{'万载古城宗祠文化馆门票成人票\\n\\n': ['¥30起'], '万载古城国学文化馆门票成人票\\n\\n': ['¥30起'], '万载古城历史文化馆门票成人票\\n\\n': ['¥30起']}"
#  '98元' '38元' "{'武功山+明月山景区等百余家景区一卡通票大小同价\\n\\n': ['¥199起']}"]
# 宜春.csv - 建议游玩时间: [nan '建议游览时间：3天 - 6天' '建议游览时间：3小时 - 5小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：12小时 - 3天' '建议游览时间：1小时 - 3小时' '建议游览时间：4小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：2小时']
# 平顶山.csv - 门票: ['具体收费情况以现场公示为主'
#  "{'六羊山通天河景区门票成人票\\n\\n': ['¥45起'], '六羊山通天河景区门票优待票\\n\\n': ['¥25起'], '六羊山通天河景区电子导览服务大小同价\\n\\n': ['¥2.9起']}"
#  '60元' "{'画眉谷电子导览服务大小同价\\n\\n': ['¥15起']}"
#  "{'中原大佛景区电子讲解票大小同价\\n\\n': ['¥10起']}"
#  "{'尧山风景区门票成人票\\n\\n': ['¥65起'], '尧山风景区门票优待票\\n\\n': ['¥35起'], '尧山风景区+景区内往返小交通门票\\n\\n': ['¥95起']}"
#  nan '具体收费情况以景区现场公示为主' '免费' '50元/人'
#  "{'阿婆寨门票成人票\\n\\n': ['¥45起'], '阿婆寨门票优待票\\n\\n': ['¥25起'], '阿婆寨门票+彩虹喊泉成人票\\n\\n': ['¥48起']}"
#  "{'九峰山门票成人票\\n\\n': ['¥30起'], '九峰山景区门票成人票\\n\\n': ['¥20起'], '九峰山门票+景交车+亲子乐园+七彩滑道+步步惊心桥+游船+丛林穿越等项目大小同价\\n\\n': ['¥138起']}"]
# 平顶山.csv - 建议游玩时间: ['建议游览时间：0.3小时 - 0.5小时' '建议游览时间：3小时 - 5小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：1小时 - 2小时' '建议游览时间：5小时 - 6小时' nan '建议游览时间：2小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：1小时 - 3小时' '建议游览时间：3天']
# 鹤壁.csv - 门票: [nan '具体收费情况以现场公示为主' '58元' '免费'
#  "{'淇河天然太极图门票成人票\\n\\n': ['¥25起'], '天然太极图电子导览服务大小同价\\n\\n': ['¥7起']}"
#  "{'淇县朝阳山景区门票成人票\\n\\n': ['¥22起'], '淇县朝阳山景区门票儿童票\\n\\n': ['¥15起'], '淇县朝阳山景区电子导览服务大小同价\\n\\n': ['¥12起']}"]
# 鹤壁.csv - 建议游玩时间: [nan '建议游览时间：12小时 - 3天' '建议游览时间：0.5小时 - 1小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：1小时 - 5小时' '建议游览时间：1小时 - 3小时']
# 三明.csv - 门票: ["{'大金湖门票+游船票+船上讲解服务成人票\\n\\n': ['¥203起'], '大金湖船票(含门票+人工讲解)门票成人票\\n\\n': ['¥163起'], '大金湖电子导览服务大小同价\\n\\n': ['¥6起']}"
#  nan
#  "{'侠天下景区+悬崖宝剑电梯+通天福手+双层玻璃悬桥票成人票\\n\\n': ['¥188起'], '侠天下景区+悬崖宝剑电梯+通天福手+双层玻璃悬桥票优待票\\n\\n': ['¥128起'], '侠天下旅游区门票+游玩套票优待票\\n\\n': ['¥128起']}"
#  "{'九龙潭门票+水上竹筏+玻璃栈道+观光车票成人票\\n\\n': ['¥100起'], '九龙潭+水上竹筏+玻璃栈道+观光车票儿童票\\n\\n': ['¥83起'], '九龙潭+水上竹筏+玻璃栈道+观光车票学生票\\n\\n': ['¥90起']}"
#  "{'玉华洞门票成人票\\n\\n': ['¥90起'], '玉华洞门票儿童票\\n\\n': ['¥47.5起'], '玉华洞门票老人票\\n\\n': ['¥47.5起']}"
#  '60元' "{'桃源洞门票成人票\\n\\n': ['¥54起'], '鳞隐石林门票成人票\\n\\n': ['¥44起']}"
#  '具体收费情况以现场公示为主'
#  "{'尚书第门票成人票\\n\\n': ['¥16.8起'], '尚书第门票老人票\\n\\n': ['¥10起'], '尚书第门票双人票\\n\\n': ['¥31.5起']}"
#  '20元'
#  "{'上清溪门票+竹筏+环保车票成人票\\n\\n': ['¥130起'], '上清溪门票+寨下大峡谷门票成人票\\n\\n': ['¥170起'], '大金湖门票+上清溪（含景交）门票成人票\\n\\n': ['¥278起']}"
#  "{'状元岩门票+观光车票成人票\\n\\n': ['¥21.97起'], '状元岩电子导览服务大小同价\\n\\n': ['¥5起']}"
#  "{'鳞隐石林门票成人票\\n\\n': ['¥44起'], '桃源洞门票成人票\\n\\n': ['¥54起'], '鳞隐石林电子导览服务大小同价\\n\\n': ['¥6起']}"
#  "{'天鹅洞群门票成人票\\n\\n': ['¥65起'], '天鹅洞电子导览服务大小同价\\n\\n': ['¥7起']}" '1.80元'
#  '68元'
#  "{'客家祖地门票成人票\\n\\n': ['¥36起'], '客家祖地门票优待票\\n\\n': ['¥20起'], '客家祖地电子导览服务大小同价\\n\\n': ['¥8起']}"
#  '10元' '50元' '具体收费情况以景区现场公示为准']
# 三明.csv - 建议游玩时间: ['建议游览时间：4小时 - 5小时' nan '建议游览时间：12小时 - 3天' '建议游览时间：1小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：2.5小时 - 3小时' '建议游览时间：1小时 - 2小时' '建议游览时间：3天' '建议游览时间：2小时']
# 呼和浩特.csv - 门票: ['具体收费情况以现场公示为主'
#  "{'内蒙古博物馆内蒙古博物院驴迹电子导览（不含门票）票大小同价\\n\\n': ['¥6起'], '希拉穆仁草原✚库布其沙漠✚魅力青城3日游（含骑马+沙漠套票）\\n\\n': ['¥880起'], '希拉穆仁草原✚响沙湾✚魅力青城纯玩3日游（含骑马+沙漠套票）\\n\\n': ['¥1280起']}"
#  '门票：40元/人\xa0 游览车10元/次，套票63元（门票+往返车票+保险）。 \n船票：60元/人、120元/人，小孩也是需要购买船票。 具体信息请以老牛湾国家地质公园当天披露为准。'
#  nan
#  "{'昭君博物院人工讲解服务+专车接送大小同价\\n\\n': ['¥499起'], '库布齐神泉沙漠景区一日游6人团纯玩 骑骆驼冲浪车黄河索道\\n\\n': ['¥288起']}"
#  "{'席力图召电子讲解票大小同价\\n\\n': ['¥7起'], '席力图召深度讲解+专车接送票大小同价\\n\\n': ['¥499起']}"
#  "{'清真大寺电子导览服务大小同价\\n\\n': ['¥5起']}" '35元' '免费开放'
#  "{'乌素图召电子导览票大小同价\\n\\n': ['¥5起']}" '5元'
#  "{'蒙牛乳业工业园区电子导览票大小同价\\n\\n': ['¥6起']}" '3元' '15元' '免费' '具体收费情况以景区现场公示为主'
#  '具体收费情况以景区现场公示为准' '具体收费情况以景区现场公示为主。' '60元'
#  "{'呼市星空艺术馆门票成人票\\n\\n': ['¥49起']}" '69元' '49元']
# 呼和浩特.csv - 建议游玩时间: ['建议游览时间：1小时 - 2小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时' nan '建议游览时间：12小时 - 3天'
#  '建议游览时间：2小时 - 4小时' '建议游览时间：2小时' '建议游览时间：0.5小时 - 2小时' '建议游览时间：1小时 - 3小时'
#  '建议游览时间：3天']
# 永州.csv - 门票: ['具体收费情况以现场公示为主' nan '35元/人' '0元'
#  "{'上甘棠博物馆门票成人票\\n\\n': ['¥18起'], '上甘棠博物馆门票儿童票\\n\\n': ['¥10起'], '上甘棠博物馆门票学生票\\n\\n': ['¥10起']}"
#  "{'江永女书园+上甘棠古村景区+千家峒大泊水景区年卡成人票\\n\\n': ['¥99起']}"
#  "{'浯溪碑林(不含门票)手绘地图、语音讲解、路线推荐门票大小同价\\n\\n': ['¥9起']}" '30元' '29元']
# 永州.csv - 建议游玩时间: ['建议游览时间：1小时' '建议游览时间：1小时 - 2小时' nan '建议游览时间：3小时 - 4小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：4小时' '建议游览时间：3小时' '建议游览时间：12小时 - 3天' '建议游览时间：2小时' '建议游览时间：3天']
# 苏州.csv - 门票: ["{'拙政园门票成人票\\n\\n': ['¥70起'], '拙政园门票老人票\\n\\n': ['¥35起'], '拙政园门票优待票\\n\\n': ['¥35起']}"
#  "{'山塘昆曲馆昆曲评弹日场门票成人票\\n\\n': ['¥48起'], '山塘昆曲馆昆曲评弹日场门票儿童票\\n\\n': ['¥36起'], '苏州古运河游船（山塘街白居易码头）古运河观光日游船票\\n\\n': ['¥72起']}"
#  "{'昆山周庄门票成人票\\n\\n': ['¥88起'], '周庄门票儿童票\\n\\n': ['¥50起'], '周庄门票学生票\\n\\n': ['¥50起']}"
#  "{'同里古镇门票成人票\\n\\n': ['¥66起'], '同里古镇门票老人票\\n\\n': ['¥50起'], '同里古镇门票优待票\\n\\n': ['¥45起']}"
#  "{'平江路历史街区VIP人工讲解服务大小同价\\n\\n': ['¥400起'], '平江路历史街区VIP人工英文讲解服务大小同价\\n\\n': ['¥628起'], '平江历史文化街区手机智能语音讲解服务成人票\\n\\n': ['¥1.3起']}"
#  "{'苏州博物馆门票+3小时私家团大咖讲师人工讲解服务大小同价\\n\\n': ['¥252起'], '苏州博物馆深度体验服务团队票\\n\\n': ['¥568起'], '苏州博物馆1.5小时文博大咖深度精讲票大小同价\\n\\n': ['¥105起']}"
#  "{'同里国家湿地公园吊床体验成人票\\n\\n': ['¥13起'], '同里国家湿地公园小火车票大小同价\\n\\n': ['¥40起'], '同里国家湿地公园一壶茶+小食拼盘票大小同价\\n\\n': ['¥88起']}"
#  "{'寒山寺门票成人票\\n\\n': ['¥17.1起'], '苏州寒山寺素斋馆素面套餐大小同价\\n\\n': ['¥18起'], '寒山寺素斋馆餐饮套餐大小同价\\n\\n': ['¥128起']}"
#  '免费' nan
#  "{'虎丘山风景名胜区门票成人票\\n\\n': ['¥60起'], '虎丘山风景名胜区门票老人票\\n\\n': ['¥30起'], '虎丘山风景名胜区门票优待票\\n\\n': ['¥30起']}"
#  "{'苏州上方山国家森林公园门票成人票\\n\\n': ['¥40起'], '苏州上方山国家森林公园门票老人票\\n\\n': ['¥20起'], '苏州上方山国家森林公园门票优待票\\n\\n': ['¥20起']}"
#  "{'金鸡湖游船桃花岛门票+往返船票成人票\\n\\n': ['¥50起'], '金鸡湖游船桃花岛门票+往返船票儿童票\\n\\n': ['¥25起'], '金鸡湖游船桃花岛门票+往返船票家庭票(2大1小)\\n\\n': ['¥120起']}"
#  "{'【酒店套餐】限售7天樱花季打卡！无锡巡塘书香府邸酒店|位于巡塘古镇，酒店三面环水，大隐于市\\n\\n': ['¥1199起']}"
#  "{'留园门票成人票\\n\\n': ['¥45起'], '留园门票老人票\\n\\n': ['¥22.5起'], '留园门票优待票\\n\\n': ['¥22.5起']}"
#  "{'苏州林屋洞门票成人票\\n\\n': ['¥31.1起'], '苏州林屋洞门票优待票\\n\\n': ['¥17.5起'], '苏州林屋洞门票亲子票(1大1小)\\n\\n': ['¥50起']}"
#  "{'昆山锦溪古镇门票成人票\\n\\n': ['¥43起'], '昆山锦溪古镇游船票成人票\\n\\n': ['¥130起'], '锦溪古镇手机智能导游讲解服务大小同价\\n\\n': ['¥1.9起']}"
#  "{'甪直古镇内景点联票成人票\\n\\n': ['¥55起'], '甪直古镇内景点联票优待票\\n\\n': ['¥39起'], '甪直古镇内景点联票亲子票(1大1小)\\n\\n': ['¥80起']}"
#  "{'苏州木渎古镇门票成人票\\n\\n': ['¥62起'], '苏州木渎古镇门票优待票\\n\\n': ['¥36起'], '木渎古镇园林实景话剧门票成人票\\n\\n': ['¥79.9起']}"
#  "{'常熟沙家浜风景区门票成人票\\n\\n': ['¥62.5起'], '常熟沙家浜风景区门票老人票\\n\\n': ['¥35起'], '沙家浜门票双人票\\n\\n': ['¥128起']}"
#  "{'苏州天平山门票成人票\\n\\n': ['¥30起'], '苏州天平山门票老人票\\n\\n': ['¥15起'], '苏州天平山门票优待票\\n\\n': ['¥15起']}"
#  '古镇旅游实行一票制，一人一票，凭票入内。\n 票价100元∕张（包括沈厅、双桥、文化街等十六个景点）。'
#  "{'苏州耦园门票成人票\\n\\n': ['¥25起'], '苏州耦园门票老人票\\n\\n': ['¥10起'], '苏州耦园门票优待票\\n\\n': ['¥10起']}"
#  "{'苏州沙溪古镇门票成人票\\n\\n': ['¥25起'], '苏州沙溪古镇门票儿童票\\n\\n': ['¥12起'], '【酒店套餐】苏州知音温德姆至尊酒店|毗邻大渠荡生态公园，三面环湖，风景优美，周末不加价\\n\\n': ['¥1199起']}"
#  "{'枫桥景区“枫桥夜泊”实景课堂大小同价\\n\\n': ['¥88起'], '枫桥景区评弹演出票大小同价\\n\\n': ['¥20起'], '枫桥景区茶楼品茗大小同价\\n\\n': ['¥39起']}"
#  '具体收费情况以现场公示为主'
#  "{'苏州沧浪亭门票成人票\\n\\n': ['¥15起'], '苏州沧浪亭门票大小同价\\n\\n': ['¥20起'], '苏州沧浪亭门票老人票\\n\\n': ['¥7.5起']}"
#  "{'网师园门票成人票\\n\\n': ['¥30起'], '网师园门票大小同价\\n\\n': ['¥268起'], '网师园门票老人票\\n\\n': ['¥15起']}"
#  "{'【酒店套餐】南浔巨人君澜度假酒店1晚+双早+双人南浔古镇大门票+可选含双人中式套餐一份★五一可预定\\n\\n': ['¥399起']}"
#  "{'昆山千灯古镇门票成人票\\n\\n': ['¥47.55起'], '千灯古镇门票老人票\\n\\n': ['¥30起'], '昆山千灯古镇门票优待票\\n\\n': ['¥25起']}"
#  "{'苏州香雪海门票成人票\\n\\n': ['¥18起'], '苏州香雪海门票老人票\\n\\n': ['¥15起'], '苏州香雪海门票优待票\\n\\n': ['¥15起']}"
#  "{'苏州重元寺门票成人票\\n\\n': ['¥13.4起'], '苏州重元寺门票双人票\\n\\n': ['¥30起'], '苏州重元寺门票三人票\\n\\n': ['¥45起']}"
#  "{'盘门门票成人票\\n\\n': ['¥35.3起'], '盘门门票大小同价\\n\\n': ['¥35.3起'], '盘门门票儿童票\\n\\n': ['¥35.9起']}"
#  "{'苏州陆巷古村门票成人票\\n\\n': ['¥58起'], '苏州陆巷古村门票优待票\\n\\n': ['¥32.5起'], '苏州启园门票成人票\\n\\n': ['¥40.5起']}"
#  '50元'
#  "{'苏州大如意圣境门票成人票\\n\\n': ['¥57起'], '苏州大如意圣境门票老人票\\n\\n': ['¥40起'], '苏州大如意圣境门票双人票\\n\\n': ['¥110起']}"
#  "{'苏州太湖湖滨国家湿地公园门票成人票\\n\\n': ['¥9起'], '太湖旅游区年卡成人票\\n\\n': ['¥148起'], '太湖旅游区年卡家庭票(2大1小)\\n\\n': ['¥258起']}"
#  '无需门票周庄古镇门票已包含。周庄日游100元，夜游80元。'
#  "{'方塔园电子导览服务大小同价\\n\\n': ['¥6起']}"
#  "{'张家港恬庄古街门票成人票\\n\\n': ['¥18起'], '张家港恬庄古街门票优待票\\n\\n': ['¥8起'], '恬庄古街驴迹电子导览（不含门票）体验大小同价\\n\\n': ['¥7起']}"
#  "{'苏州大阳山植物园景区门票成人票\\n\\n': ['¥45起'], '大阳山植物园门票儿童票\\n\\n': ['¥25起'], '苏州大阳山植物园景区门票学生票\\n\\n': ['¥25起']}"]
# 苏州.csv - 建议游玩时间: ['建议游览时间：2小时 - 3小时' '建议游览时间：2小时 - 4小时' '建议游览时间：3天 - 6天' '建议游览时间：12小时 - 3天'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：1小时 - 2小时' nan '建议游览时间：12小时' '建议游览时间：1小时'
#  '建议游览时间：2小时' '建议游览时间：3小时' '建议游览时间：3天 - 9天' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：0.5小时' '建议游览时间：1小时 - 3小时' '建议游览时间：3天' '建议游览时间：4小时'
#  '建议游览时间：1.5小时 - 2小时' '建议游览时间：3小时 - 5小时']
# 丽水.csv - 门票: ["{'仙都景区门票成人票\\n\\n': ['¥93.8起'], '缙云仙都门票+景交车票儿童票\\n\\n': ['¥55起'], '缙云仙都门票+景交车票老人票\\n\\n': ['¥65起']}"
#  "{'云和梯田门票成人票\\n\\n': ['¥40起'], '云和梯田门票+往返索道票成人票\\n\\n': ['¥195起'], '云和梯田门票+往返索道+下午茶票双人票\\n\\n': ['¥499起']}"
#  "{'古堰画乡景区门票+双程船票成人票\\n\\n': ['¥45起'], '古堰画乡景区门票+双程船票儿童票\\n\\n': ['¥25起'], '古堰画乡景区门票+巴比松星空体验馆门票成人票\\n\\n': ['¥68起']}"
#  nan
#  "{'神龙谷门票成人票\\n\\n': ['¥47起'], '神龙谷门票儿童票\\n\\n': ['¥35起'], '神龙谷电子导览服务大小同价\\n\\n': ['¥10起']}"
#  '具体收费情况以现场公示为主'
#  "{'中国青瓷小镇·披云青瓷文化园门票成人票\\n\\n': ['¥50起'], '披云青瓷文化园电子导览服务大小同价\\n\\n': ['¥9起']}"
#  '免费' '包含在古堰画乡景区门票内'
#  '门票\n 千丝岩石文化公园门票20元，石雕文化旅游区套票60元（含千丝岩石文化公园和博物馆门票）\n\n优惠信息\n 1.2米以下的儿童和70周岁的老可免票；\n 1.2米-1.4的儿童、军官、教师等持相关证件到景区可购优惠票'
#  "{'石门洞门票成人票\\n\\n': ['¥50起'], '石门洞门票优待票\\n\\n': ['¥25起'], '石门洞门票老人票\\n\\n': ['¥25起']}"
#  "{'千峡湖生态旅游度假区峡湾观光游船票成人票\\n\\n': ['¥90起'], '千峡湖生态旅游度假区峡湾观光游船票优待票\\n\\n': ['¥75起']}"
#  "{'南明山电子导览票大小同价\\n\\n': ['¥7起']}" "{'黄家大院电子导览服务大小同价\\n\\n': ['¥7起']}"
#  '缆车往返220元一位;景交车100元一位;套票优惠价格220元一位。' '60元'
#  "{'大小洞天门票+电瓶车票大小同价\\n\\n': ['¥25起'], '大小洞天摩托艇体验大小同价\\n\\n': ['¥160起'], '大小洞天玻璃观光船特色观景票大小同价\\n\\n': ['¥168起']}"
#  "{'★包船送红酒★三亚游艇出海租赁包艇|拼船送潜水+自驾体验海钓商务团建/生日/求婚/DJ轰趴\\n\\n': ['¥88起'], '★专业钓鱼艇 ★三亚出海纯海钓2-9人团鱼竿鱼饵空调卫生间现钓现吃\\n\\n': ['¥148起']}"
#  '50元' '包含在南山文化旅游景区门票内，通用南山文化旅游景区门票。'
#  '票价 \n 购买了大小洞天的门票（135元）后即可免费参观。\n\n\n优惠政策 \n 1、身高1.2米以下儿童免票；身高1.2-1.4米儿童，门票半价优惠（70元）。\n 2、60-69周岁老年人凭有效证件，门票半价优惠（70元）；70周岁以上（含70周岁）老年人凭有效证件免票。\n 3、大、中、小学学生（不含成人教育学生）凭学生证，门票半价优惠（70元）。\n 4、现役军人、离退休军人、残疾军人凭有效证件免票。5、残疾人凭有效证件，免票。'
#  '包含在南山大小洞天景区内，通用于南山大小洞天景区门票。' '0元' '90元' '需购买蜈支洲岛门票方可入园使用'
#  '包含于大小洞天景区内，通用大小洞天景区门票。'
#  "{'南山文化旅游区门票成人票\\n\\n': ['¥122起'], '南山文化旅游区门票+游览车票成人票\\n\\n': ['¥152起'], '南山文化旅游区门票+海上观音游船票成人票\\n\\n': ['¥198起']}"
#  '景区暂时停业，具体开放时间可见景区公示。'
#  '票价\n 1、旺季：散客101元，旅行社团队101元，优惠票50元。\n 2、淡季：散客85元，旅行社团队85元，优惠票45元，其中含政府价调基金5元。\n\n 优惠政策\n 1、学生、60-69岁老人、残疾人凭有效证件，身高1.2-1.4米之间儿童，按旺季50元，淡季45元购票入园。\n 2、现役军人、革命伤残军人和离退休军人及70岁（含70岁）以上老人凭有效证件，身高1.2米以下儿童，可免票入园，其他人员免票按国家和省市有关规定执行。 \n\n Tips\n 1、一般地，旺季指的是每年10月1日至次年4月30日，淡季指的是每年5月1日至9月30日。\n 2、每年6月1日定为景区免费开放日，持本省有效证件（户口薄或身份证）可免票入园游览。'
#  '票价\n 仅参观码头免费，入岛成人票：148元/人(含船票)\n\n优惠政策\n 身高1.1-1.4米儿童，海南本地居民、省内就读学生、现役军人、新闻记者凭有效证件享受优惠门票； \n 免费票范围：1.1米以下儿童； 注：70岁以上老人不免票。\n\nTips\n 以上门票包括景区门票价格和码头到岛上的往返船票费用。'
#  '票价\n 1、旺季：散客101元，旅行社团队101元，优惠票50元。\n 2、淡季：散客85元，旅行社团队85元，优惠票45元，其中含政府价调基金5元。\n\n 优惠政策\n 1、学生、60-69岁老人、残疾人凭有效证件，身高1.2-1.4米之间儿童，按旺季50元，淡季45元购票入园。\n 2、现役军人、革命伤残军人和离退休军人及70岁（含70岁）以上老人凭有效证件，身高1.2米以下儿童，可免票入园，其他人员免票按国家和省市有关规定执行。\n\n Tips\n 1、一般地，旺季指的是每年10月1日至次年4月30日，淡季指的是每年5月1日至9月30日。\n 2、每年6月1日定为景区免费开放日，持本省有效证件（户口薄或身份证）可免票入园游览。'
#  "{'库布齐沙漠经典A套票成人票\\n\\n': ['¥260起'], '库布齐沙漠豪华D套票成人票\\n\\n': ['¥380起'], '库布其沙漠经典B套票成人票\\n\\n': ['¥280起']}"
#  "{'成吉思汗陵门票成人票\\n\\n': ['¥90起'], '成吉思汗陵门票学生票\\n\\n': ['¥45起'], '成吉思汗陵门票老人票\\n\\n': ['¥45起']}"
#  '60元' '具体收费情况以现场公示为主' "{'恩格贝旅游区电子导览票大小同价\\n\\n': ['¥9起']}" nan
#  "{'萨拉乌苏旅游区门票优待票\\n\\n': ['¥25起']}" '150元' '具体收费情况以景区现场公示为主。' '30元'
#  '11月-次年3月：20元；4月-10月：70元。' '免费' '成人票——10元；儿童票——5元']
# 鄂尔多斯.csv - 建议游玩时间: ['建议游览时间：2小时 - 1天' '建议游览时间：6小时' '建议游览时间：12小时 - 3天' '建议游览时间：3小时 - 4小时'
#  '建议游览时间：3天' '建议游览时间：2小时 - 3小时' '建议游览时间：4小时 - 5小时' nan '建议游览时间：4小时 - 6小时'
#  '建议游览时间：1小时 - 3小时' '建议游览时间：3小时 - 5小时' '建议游览时间：4小时' '建议游览时间：1小时'
#  '建议游览时间：0.5小时 - 1小时' '建议游览时间：1小时 - 2小时' '建议游览时间：3小时']
# 儋州.csv - 门票: ["{'东坡书院门票成人票\\n\\n': ['¥23起'], '海南儋州海上跳伞俱乐部【专业教练带跳/空中俯览海花岛】\\n\\n': ['¥1000起']}"
#  '具体收费情况以现场公示为主' nan
#  "{'海南热带植物园门票成人票\\n\\n': ['¥25.9起'], '海南热带植物园门票儿童票\\n\\n': ['¥13起'], '海南热带植物园门票学生票\\n\\n': ['¥13起']}"
#  '免费' '景区免费进入，景区内游玩项目单独收费。' '35元' '68元' '景区现暂停营业，具体开放时间以景区公示为准。'
#  "{'石花水洞门票成人票\\n\\n': ['¥60起'], '石花水洞门票学生票\\n\\n': ['¥35起'], '石花水洞门票老人票\\n\\n': ['¥35起']}"]
# 儋州.csv - 建议游玩时间: ['建议游览时间：1小时' nan '建议游览时间：2小时 - 3小时' '建议游览时间：12小时 - 3天' '建议游览时间：1小时 - 4小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：1小时 - 2小时' '建议游览时间：1小时 - 3小时' '建议游览时间：3天 - 6天'
#  '建议游览时间：2小时']
# 绵阳.csv - 门票: ["{'越王楼门票成人票\\n\\n': ['¥44.4起'], '越王楼门票优待票\\n\\n': ['¥25起'], '越王楼电子导览服务大小同价\\n\\n': ['¥6起']}"
#  "{'罗浮山会议中心温泉度假区票儿童票\\n\\n': ['¥50起']}" nan '1元'
#  "{'罗浮山羌王城门票成人票\\n\\n': ['¥34.6起'], '罗浮山羌王城门票学生票\\n\\n': ['¥20起'], '罗浮山羌王城门票老人票\\n\\n': ['¥20起']}"
#  '免费' '具体收费情况以现场公示为主'
#  "{'江油李白故里门票成人票\\n\\n': ['¥36起'], '江油李白故里门票儿童票\\n\\n': ['¥20起'], '江油李白故里门票学生票\\n\\n': ['¥20起']}"
#  "{'七曲山大庙门票成人票\\n\\n': ['¥35起'], '七曲山大庙门票优待票\\n\\n': ['¥18起'], '水观音风景区门票成人票\\n\\n': ['¥15起']}"
#  "{'寻龙山景区门票成人票\\n\\n': ['¥60起'], '寻龙山景区门票优待票\\n\\n': ['¥35起'], '寻龙山手机导游(不含门票)手绘地图、语音讲解票大小同价\\n\\n': ['¥7起']}"
#  '40元' '80元' '成人：80元 儿童：40元' '50元'
#  "{'佛爷洞景区门票+暗河船票成人票\\n\\n': ['¥65起'], '佛爷洞景区门票+暗河船票双人票\\n\\n': ['¥125起'], '佛爷洞景区门票+暗河船票优待票\\n\\n': ['¥35起']}"
#  '30元' '10元' '具体收费情况以景区现场公示为主' '25元']
# 绵阳.csv - 建议游玩时间: ['建议游览时间：1小时 - 2小时' '建议游览时间：2小时 - 3小时' nan '建议游览时间：3小时' '建议游览时间：1小时'
#  '建议游览时间：3天' '建议游览时间：3小时 - 5小时' '建议游览时间：2小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：1小时 - 4小时' '建议游览时间：1小时 - 3小时' '建议游览时间：2小时 - 4小时'
#  '建议游览时间：3小时 - 4小时' '建议游览时间：0.5小时 - 1小时' '建议游览时间：0.5小时 - 2小时']
# 防城港.csv - 门票: ["{'东兴一日游【万尾金滩+海上红树林+国门边境风情+海淘美食特产精选纯玩团】\\n\\n': ['¥198起'], '东兴一日游【国界之南越南边界游+海淘美食】\\n\\n': ['¥198起']}"
#  nan '具体收费情况以现场公示为主'
#  "{'东兴一日游【国界之南越南边界游+海淘美食】\\n\\n': ['¥198起'], '越南芒街+东兴口岸一日游【身份证出国+异国风情+海淘美食】\\n\\n': ['¥298起'], '东兴一日游【万尾金滩+海上红树林+国门边境风情+海淘美食特产精选纯玩团】\\n\\n': ['¥198起']}"
#  "{'防城港江山半岛白浪滩景区出海拉网捕鱼体验成人票\\n\\n': ['¥450起']}" '免费' '158元' '128元' '4元'
#  '189元' '景区免费，景区内项目按实际收费' '收费']
# 防城港.csv - 建议游玩时间: ['建议游览时间：2小时' nan '建议游览时间：0.5小时 - 1小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：3天' '建议游览时间：1小时' '建议游览时间：3小时 - 4小时'
#  '建议游览时间：4小时 - 5小时' '建议游览时间：12小时 - 3天' '建议游览时间：0.5小时 - 2小时' '建议游览时间：3小时']
# 西双版纳.csv - 门票: ["{'中国科学院西双版纳热带植物园门票成人票\\n\\n': ['¥75起'], '中国科学院西双版纳热带植物园门票+全园电瓶车票成人票\\n\\n': ['¥175起'], '中国科学院西双版纳热带植物园门票+西区电瓶车票成人票\\n\\n': ['¥125起']}"
#  nan
#  "{'野象谷门票成人票\\n\\n': ['¥56.2起'], '野象谷门票双人票\\n\\n': ['¥113起'], '野象谷门票三人票\\n\\n': ['¥160起']}"
#  "{'湄公河六国水上市场内湖游船票成人票\\n\\n': ['¥60起'], '湄公河六国水上市场内湖游船票儿童票\\n\\n': ['¥30起'], '告庄西双景无人机拍摄套餐服务大小同价\\n\\n': ['¥228起']}"
#  "{'景洪曼听公园门票成人票\\n\\n': ['¥35起'], '景洪曼听公园门票双人票\\n\\n': ['¥76起'], '景洪曼听公园门票三人票\\n\\n': ['¥120起']}"
#  "{'傣族园门票成人票\\n\\n': ['¥38.5起'], '傣族园门票双人票\\n\\n': ['¥90起'], '傣族园门票三人票\\n\\n': ['¥135起']}"
#  "{'西双版纳热带雨林国家公园望天树景区门票+单程游船票成人票\\n\\n': ['¥95起'], '西双版纳热带雨林国家公园望天树景区门票+单程游船+树冠走廊+往返直通车票成人票\\n\\n': ['¥242起'], '望天树景区+单程游船+观光车+树冠走廊套票成人票\\n\\n': ['¥170起']}"
#  "{'西双版纳热带动物园门票成人票\\n\\n': ['¥39起'], '西双版纳热带动物园门票儿童票\\n\\n': ['¥20起'], '西双版纳热带动物园门票老人票\\n\\n': ['¥20起']}"
#  "{'西双版纳原始森林公园门票成人票\\n\\n': ['¥36起'], '西双版纳原始森林公园门票双人票\\n\\n': ['¥74起'], '西双版纳原始森林公园门票三人票\\n\\n': ['¥112起']}"
#  "{'曼听公园门票+西双版纳总佛寺门票成人票\\n\\n': ['¥37.5起'], ' 西双版纳总佛寺门票成人票\\n\\n': ['¥38起'], '景洪曼听公园门票成人票\\n\\n': ['¥35起']}"
#  "{'澜沧江游轮【水果饮料+表演+歌舞+船票】票成人票\\n\\n': ['¥235起'], '澜沧江漂流澜沧江快艇（门口取票）门票成人票\\n\\n': ['¥188起'], '中缅国门+勐景来+独树成林一日游 网红导游+傣味中餐【两种游玩方式任选】\\n\\n': ['¥48起']}"
#  "{'西双版纳雨林谷门票成人票\\n\\n': ['¥135起'], '西双版纳雨林谷门票+往返直通车票成人票\\n\\n': ['¥248起'], '西双版纳包车一日游纯玩任意搭配景区定制行（专车零等待不拼车）\\n\\n': ['¥100起']}"
#  "{'中缅国门+勐景来+独树成林一日游 网红导游+傣味中餐【两种游玩方式任选】\\n\\n': ['¥48起'], '西双版纳打洛＋勐景来＋独树成林＋南糯山【优质精选/全程金牌讲解员/中缅边境哈国门/特色餐】\\n\\n': ['¥135起']}"
#  "{'基诺山寨门票成人票\\n\\n': ['¥131起'], '基诺山寨门票双人票\\n\\n': ['¥260起'], '基诺山寨门票+市区往返景区直通车票成人票\\n\\n': ['¥188起']}"
#  "{'西双版纳原始森林公园+基诺山+傣家自然村寨一日游（门票+独立用车+亲近自然）\\n\\n': ['¥68起'], '私家团 曼听公园+傣族园包车纯玩一日游*独立用车含2景区门票\\n\\n': ['¥40起'], '私家团 西双版纳基诺山寨+原始森林公园+傣家自然村寨一日游 含门票\\n\\n': ['¥268起']}"
#  '具体收费情况以现场公示为主'
#  "{'勐巴拉娜西歌舞秀门票成人票\\n\\n': ['¥240起'], '勐巴拉娜西歌舞秀门票双人票\\n\\n': ['¥485起'], '勐巴拉娜西超级歌舞秀门票成人票(普通票)\\n\\n': ['¥200起']}"
#  "{'热带花卉园门票成人票\\n\\n': ['¥38起'], '热带花卉园门票双人票\\n\\n': ['¥80起'], '西双版纳热带花卉园门票+电瓶车票成人票\\n\\n': ['¥70起']}"
#  '成人票60人民币'
#  "{'勐景来门票成人票\\n\\n': ['¥45起'], '勐景来门票双人票\\n\\n': ['¥90起'], '勐景来+独树成林+打洛中缅国门+往返景区直通车票成人票\\n\\n': ['¥98起']}"
#  "{'独树成林门票成人票\\n\\n': ['¥29起'], '独树成林门票+往返电瓶车成人票\\n\\n': ['¥58起'], '勐景来+独树成林+打洛中缅国门+往返景区直通车票成人票\\n\\n': ['¥98起']}"
#  "{'南糯山门票+往返景区直通车票大小同价\\n\\n': ['¥100起'], '私家团 精品2日游 野象谷＋森林公园＋南糯古茶山＋曼丢古寨|轻奢小团|单团单发|酒店接送|赠送门票|\\n\\n': ['¥388起'], '私家团| 西双版纳南糯山一日游  免费采茶制茶体验＋酒店接送\\n\\n': ['¥70起']}"
#  '免费'
#  "{'中缅国门+勐景来+独树成林一日游 网红导游+傣味中餐【两种游玩方式任选】\\n\\n': ['¥48起'], '西双版纳温西礼露营地\\n\\n': ['¥270起']}"
#  '暂停营业，具体开放时间以景区公告为准或电话咨询景区。原门市价为：20元。' '60元' '5元'
#  "{'大益庄园电子导览服务大小同价\\n\\n': ['¥9起'], '西双版纳温西礼露营地\\n\\n': ['¥270起']}"
#  '需先购买望天树景区门票' '10元' '30元'
#  "{'西双版纳南药园景区门票成人票\\n\\n': ['¥20起'], '南药园电子导览服务大小同价\\n\\n': ['¥7起']}"
#  '具体收费情况以景区现场公示为主']
# 西双版纳.csv - 建议游玩时间: ['建议游览时间：2小时 - 3小时' '建议游览时间：3小时 - 5小时' '建议游览时间：12小时 - 3天' '建议游览时间：12小时'
#  nan '建议游览时间：1小时 - 2小时' '建议游览时间：1小时 - 3小时' '建议游览时间：3小时' '建议游览时间：6天'
#  '建议游览时间：1小时' '建议游览时间：0.5小时 - 2小时' '建议游览时间：2小时' '建议游览时间：2小时 - 5小时'
#  '建议游览时间：3天' '建议游览时间：0.5小时 - 1小时' '建议游览时间：3天 - 6天' '建议游览时间：3小时 - 4小时']
# 营口.csv - 门票: [nan '具体收费情况以现场公示为主' '10.00元' '10元'
#  "{'望儿山门票成人票\\n\\n': ['¥19.6起'], '望儿山电子导览服务大小同价\\n\\n': ['¥6起'], '【酒店套餐】望儿山温泉水乐园度假酒店+含双早+双人单次温泉门票\\n\\n': ['¥458起']}"
#  '70元' '具体收费情况以景区现场公示为主。' '60元']
# 营口.csv - 建议游玩时间: [nan '建议游览时间：2小时 - 3小时' '建议游览时间：1小时' '建议游览时间：3小时 - 4小时' '建议游览时间：3小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：2小时' '建议游览时间：0.5小时 - 1小时' '建议游览时间：12小时 - 3天']
# 甘孜.csv - 门票: ["{'稻城亚丁门票+观光大巴车票成人票\\n\\n': ['¥266起'], '稻城亚丁手机智能导游服务大小同价\\n\\n': ['¥0.9起'], '《亚丁密码》冒险秀(蓝区VIP区)演出票+稻城亚丁（含观光车）门票成人票\\n\\n': ['¥578起']}"
#  nan
#  '建议游览时间：12小时 - 3天' '建议游览时间：3天' '建议游览时间：0.2小时 - 0.3小时' '建议游览时间：12小时'
#  '建议游览时间：4小时 - 5小时' '建议游览时间：0.5小时' '建议游览时间：0.3小时 - 0.5小时'
#  '建议游览时间：0.5小时 - 1小时' '建议游览时间：0.5小时 - 5小时' '建议游览时间：4小时 - 6小时'
#  '建议游览时间：5小时 - 7小时' '建议游览时间：0.1小时 - 0.2小时']
# 葫芦岛.csv - 门票: [nan "{'觉华岛电子导览服务大小同价\\n\\n': ['¥6起']}" '具体收费情况以景区现场公示为主。'
#  "{'九门口水上长城门票+隧道票成人票\\n\\n': ['¥50起'], '九门口水上长城电子导览服务大小同价\\n\\n': ['¥6起']}"
#  '具体收费情况以现场公示为主'
#  "{'葫芦古镇旅游度假区观光票成人票\\n\\n': ['¥29.9起'], '葫芦古镇旅游度假区观光票优待票\\n\\n': ['¥20起'], '葫芦古镇旅游度假区观光票双人票\\n\\n': ['¥65起']}"
#  "{'灵山风景名胜区门票成人票\\n\\n': ['¥45起'], '灵山风景名胜区门票优待票\\n\\n': ['¥25起']}" '10元']
# 葫芦岛.csv - 建议游玩时间: [nan '建议游览时间：3小时 - 4小时' '建议游览时间：3天 - 6天' '建议游览时间：3小时' '建议游览时间：2小时 - 3小时'
#  '建议游览时间：2小时 - 4小时' '建议游览时间：6天 - 9天' '建议游览时间：19.2小时 - 3天'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：12小时 - 3天' '建议游览时间：3小时 - 5小时' '建议游览时间：1小时'
#  '建议游览时间：0.5小时 - 0.7小时' '建议游览时间：2小时']
# 四平.csv - 门票: [nan '具体收费情况以现场公示为主' '免费' '30元' '25元，庙会门票6元' '20元/人' '19元']
# 四平.csv - 建议游玩时间: [nan '建议游览时间：1小时 - 2小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时' '建议游览时间：2小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：0.5小时 - 2小时']
# 汕头.csv - 门票: ["{'南澳岛渔船观光+捕鱼体验成人票\\n\\n': ['¥288起'], '南澳岛渔船观光+捕鱼体验儿童票\\n\\n': ['¥140起'], '南澳岛浮潜体验成人票\\n\\n': ['¥288起']}"
#  nan '具体收费情况以现场公示为主' '免费'
#  "{'海门莲花峰海洋文化馆门票成人票\\n\\n': ['¥68起'], '海门莲花峰海洋文化馆门票儿童票\\n\\n': ['¥38起'], '海门莲花峰海洋文化馆门票优待票\\n\\n': ['¥38起']}"
#  "{'宋井门票成人票\\n\\n': ['¥15起'], '宋井门票优待票\\n\\n': ['¥8起'], '【2-12人精品小团】潮州汕头上门接送/南澳岛秘境探索一日游\\n\\n': ['¥188起']}"
#  "{'南澳总兵府门票票成人票\\n\\n': ['¥12起'], '金银岛门票成人票\\n\\n': ['¥5.5起'], '金银岛门票优待票\\n\\n': ['¥3起']}"
#  "{'宋井门票成人票\\n\\n': ['¥15起'], '宋井门票优待票\\n\\n': ['¥8起'], '金银岛门票成人票\\n\\n': ['¥5.5起']}"
#  '具体收费情况以景区现场公示为主']
# 汕头.csv - 建议游玩时间: ['建议游览时间：3天 - 6天' nan '建议游览时间：0.5小时 - 1小时' '建议游览时间：3小时 - 4小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 3小时' '建议游览时间：4小时 - 5小时' '建议游览时间：3小时'
#  '建议游览时间：1小时 - 2小时' '建议游览时间：2小时']
# 资阳.csv - 门票: ['具体收费情况以现场公示为主' nan "{'成都同道野梵七彩田园露营地\\n\\n': ['¥50起']}"
#  "{'陈毅故居手机导游(不含门票)手绘地图、语音讲解票大小同价\\n\\n': ['¥9起']}" '2元']
# 资阳.csv - 建议游玩时间: ['建议游览时间：1小时 - 2小时' nan '建议游览时间：2小时 - 4小时' '建议游览时间：0.5小时 - 1小时'
#  '建议游览时间：2小时 - 3小时' '建议游览时间：2小时' '建议游览时间：3小时' '建议游览时间：12小时 - 3天'
#  '建议游览时间：1小时 - 3小时']
# 益阳.csv - 门票: [nan '45元' '具体收费情况以现场公示为主' '0元/人' '免费' '100元' '部分区域/项目收费，具体收费情况以景区现场公示为主'
#  '具体收费情况以景区现场公示为主。' "{'安宁竹谷生态景区电子导览服务大小同价\\n\\n': ['¥5起']}"
#  "{'天意木国门票大小同价\\n\\n': ['¥83起']}" '内部项目收费']
# 益阳.csv - 建议游玩时间: [nan '建议游览时间：3小时 - 4小时' '建议游览时间：1小时' '建议游览时间：2小时 - 3小时' '建议游览时间：1小时 - 2小时'
#  '建议游览时间：2小时 - 4小时' '建议游览时间：1小时 - 3小时' '建议游览时间：2小时' '建议游览时间：3小时'
#  '建议游览时间：12小时' '建议游览时间：12小时 - 3天']
# 沧州.csv - 门票: ["{'河间府署门票成人票\\n\\n': ['¥34起'], '河间府署门票双人票\\n\\n': ['¥60起'], '沧州河间府署手机导游(不含门票)服务成人票\\n\\n': ['¥8起']}"
#  '具体收费情况以现场公示为主' '成人票30元，儿童票15元'
#  "{'南大港湿地门票成人票\\n\\n': ['¥39.99起'], '南大港湿地电子讲解票大小同价\\n\\n': ['¥7起']}" nan
#  '0元' '99元' '免费' '具体详情以景区公示为准。']
# 沧州.csv - 建议游玩时间: ['建议游览时间：1小时 - 2小时' '建议游览时间：1小时' '建议游览时间：2小时' nan '建议游览时间：2小时 - 3小时'
#  '建议游览时间：12小时 - 3天' '建议游览时间：2小时 - 4小时']
#      City                                           名字   评分
# 0      定西                                          首阳山  5.0
# 1      定西               狼渡湿地草原Langdu Wetland Grassland  5.0
# 2      定西                      临洮县博物馆Lintaoxian Museum  5.0
# 3      定西  定西市马家窑彩陶博物馆Dingxishi Majiayao Caitao Museum  5.0
# 4      定西                     通渭县博物馆Tongweixian Museum  5.0
# ...   ...                                          ...  ...
# 2558   沧州                                    任丘市张华绿色公园  5.0
# 2559   沧州                                    滨海恒大文化旅游城  5.0
# 2560   沧州               南皮县民俗博物馆Nanpixian Minsu Museum  5.0
# 2561   沧州             任丘市京南博物馆Renqiushi Jingnan Museum  5.0
# 2562   沧州               任丘新市民广场Renqiuxin Shimin Square  5.0
#
# [2563 rows x 3 columns]
#      City                                           名字   评分
# 0      定西                                          首阳山  5.0
# 1      定西               狼渡湿地草原Langdu Wetland Grassland  5.0
# 2      定西                      临洮县博物馆Lintaoxian Museum  5.0
# 3      定西  定西市马家窑彩陶博物馆Dingxishi Majiayao Caitao Museum  5.0
# 4      定西                     通渭县博物馆Tongweixian Museum  5.0
# ...   ...                                          ...  ...
# 2466   成都                    千佛和平塔Qianfo Heping Pagoda  5.0
# 2467   成都                                        成都爱道堂  5.0
# 2468   成都                                      大溪谷旅游景区  5.0
# 2469   成都                            花楸村Huaqiu Village  5.0
# 2470   成都                                   白鹿中法传统风情小镇  5.0
#
# [309 rows x 3 columns]

# %%
# 初始化新的列 '建议游玩时间'
filtered_result_df['建议游玩时间'] = np.nan

# 遍历CSV文件并更新建议游玩时间
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        city_name = filename[:-4]
        city_data = pd.read_csv(os.path.join(directory, filename))
        
        # 筛选出filtered_result_df中当前城市的景点
        city_spots = filtered_result_df[filtered_result_df['City'] == city_name]
        
        # 遍历当前城市的景点并更新建议游玩时间
        for idx, spot in city_spots.iterrows():
            match = city_data[city_data['名字'] == spot['名字']]
            if not match.empty:
                filtered_result_df.loc[idx, '建议游玩时间'] = match['建议游玩时间'].values[0]

# 去掉建议游玩时间为NaN的数据
filtered_result_df = filtered_result_df.dropna(subset=['建议游玩时间'])

# 输出结果
filtered_result_df
# Out:
#      City                                           名字   评分            建议游玩时间
# 1      定西               狼渡湿地草原Langdu Wetland Grassland  5.0  建议游览时间：12小时 - 3天
# 2      定西                      临洮县博物馆Lintaoxian Museum  5.0  建议游览时间：1小时 - 2小时
# 3      定西  定西市马家窑彩陶博物馆Dingxishi Majiayao Caitao Museum  5.0        建议游览时间：3小时
# 6      定西                       二郎山Erlangshan Mountain  5.0  建议游览时间：12小时 - 3天
# 7      定西                 灞陵桥公园Weiyuan Balingqiao Park  5.0  建议游览时间：1小时 - 2小时
# ...   ...                                          ...  ...               ...
# 2464   成都                              远拓新津白鹤滩国家湿地公园营地  5.0  建议游览时间：4小时 - 5小时
# 2465   成都                               楠木溪Nanmu Brook  5.0         建议游览时间：3天
# 2467   成都                                        成都爱道堂  5.0  建议游览时间：1小时 - 2小时
# 2469   成都                            花楸村Huaqiu Village  5.0  建议游览时间：1小时 - 2小时
# 2470   成都                                   白鹿中法传统风情小镇  5.0  建议游览时间：1小时 - 2小时
#
# [115 rows x 4 columns]

# %%
# Ensure all values in '建议游玩时间' are treated as strings
filtered_result_df['建议游玩时间'] = filtered_result_df['建议游玩时间'].astype(str)

def convert_time_to_hours(time_str):
    time_str = time_str.replace('建议游览时间：', '').replace('天', '*24').replace('小时', '')
    min_time = eval(time_str.split(' - ')[0])
    return min_time

filtered_result_df['建议游玩时间'] = filtered_result_df['建议游玩时间'].apply(convert_time_to_hours)

filtered_result_df
# Out:
#      City                                           名字   评分  建议游玩时间
# 1      定西               狼渡湿地草原Langdu Wetland Grassland  5.0    12.0
# 2      定西                      临洮县博物馆Lintaoxian Museum  5.0     1.0
# 3      定西  定西市马家窑彩陶博物馆Dingxishi Majiayao Caitao Museum  5.0     3.0
# 6      定西                       二郎山Erlangshan Mountain  5.0    12.0
# 7      定西                 灞陵桥公园Weiyuan Balingqiao Park  5.0     1.0
# ...   ...                                          ...  ...     ...
# 2464   成都                              远拓新津白鹤滩国家湿地公园营地  5.0     4.0
# 2465   成都                               楠木溪Nanmu Brook  5.0    72.0
# 2467   成都                                        成都爱道堂  5.0     1.0
# 2469   成都                            花楸村Huaqiu Village  5.0     1.0
# 2470   成都                                   白鹿中法传统风情小镇  5.0     1.0
#
# [115 rows x 4 columns]

# %%
import re
# 初始化新的列 '建议游玩时间'
filtered_result_df['门票'] = np.nan

# 遍历CSV文件并更新建议游玩时间
for filename in os.listdir(directory):
    if filename.endswith('.csv'):
        city_name = filename[:-4]
        city_data = pd.read_csv(os.path.join(directory, filename))
        
        # 筛选出filtered_result_df中当前城市的景点
        city_spots = filtered_result_df[filtered_result_df['City'] == city_name]
        
        # 遍历当前城市的景点并更新建议游玩时间
        for idx, spot in city_spots.iterrows():
            match = city_data[city_data['名字'] == spot['名字']]
            if not match.empty:
                filtered_result_df.loc[idx, '门票'] = match['门票'].values[0]

# 处理门票字段
def adjust_ticket_price(ticket):
    if isinstance(ticket, str):
        if '免费' in ticket:
            return 0
        elif '具体收费情况以景区现场公示为主。' in ticket:
            return np.nan
        elif '元' in ticket:
            price = re.findall(r'\d+', ticket)
            if price:
                return int(price[0])
        elif '￥' in ticket or '¥' in ticket:
            price = re.findall(r'\d+', ticket)
            if price:
                return int(price[0])
    return np.nan  # 如果没有匹配到任何情况，将其设置为NaN

filtered_result_df['门票'] = filtered_result_df['门票'].apply(adjust_ticket_price)

# 计算门票列的均值
mean_value = filtered_result_df['门票'].mean()

# 用均值填充NaN值
filtered_result_df['门票'].fillna(mean_value, inplace=True)

# 将门票列转换为整数类型
filtered_result_df['门票'] = filtered_result_df['门票'].astype(int)

# 计算每个城市的最短游玩时间
shortest_visit_time_df = filtered_result_df.loc[filtered_result_df.groupby('City')['建议游玩时间'].idxmin()]

# 输出结果
shortest_visit_time_df
# Out:
#      City                                                 名字   评分  建议游玩时间   门票
# 278    三亚                                   太阳湾路Sun Bay Road  5.0     0.5   52
# 1709   中山                                                虎逊岩  5.0     1.0   52
# 1253   临高                                        茉莉轩Molixuan  5.0     2.0   52
# 1609   丽江                                                泸源涯  5.0     0.5    0
# 2262  佳木斯                                    乌苏大桥Wusu Bridge  5.0     0.5   52
# 799    包头                         希拉穆仁花海Xilamuren Flower Sea  5.0     2.0   52
# 1926   北京                                 长城公园Changchen Park  5.0     1.0   52
# 343    台州                                     石塘镇Shitangzhen  5.0    12.0   52
# 1010   咸宁                                           康丰源生态旅游区  5.0    12.0   52
# 908    唐山                                               伯雍公园  5.0     1.0   52
# 673   嘉峪关                                                左公柳  5.0     0.5    0
# 1909   大理                                    廊桥Lounge Bridge  5.0     0.5   52
# 1999   安庆                                            皖鄂大峡谷漂流  5.0     2.0   52
# 2      定西                            临洮县博物馆Lintaoxian Museum  5.0     1.0    0
# 1404   宝鸡                                               天圆地方  5.0     3.0   52
# 1994   宿迁                            夫子庙（泗阳）Confucius Temple  5.0     1.0   52
# 738    常德       桃花山景区滑杆Slider in Taohua Mountain Scenic Area  5.0     0.5   52
# 1340   忻州                                 寿宁寺Shouning Temple  5.0     1.0   52
# 76     恩施                                              恩施不夜城  5.0     1.0   52
# 2467   成都                                              成都爱道堂  5.0     1.0    0
# 767    扬州                                               高邮东湖  5.0     1.0    0
# 718   攀枝花                     望月楼 Wangyue TowerWangyue Tower  5.0     1.0   52
# 299    晋城                                             玉庭宫博览馆  5.0     1.0   52
# 1558   朔州                           广武汉墓Han Tombs at Guangwu  5.0     1.0   52
# 1783   杭州                                    富春江Fuchun River  5.0     1.0    1
# 132    汕尾                                   南海寺Nanhai Temple  5.0     1.0   52
# 536    沈阳                                              东北神学院  5.0     1.0   52
# 1119   泸州                                             泸州市植物园  5.0     1.0   52
# 2267   济源                                              济源牡丹园  5.0     1.0   52
# 565    潍坊                                             潭溪山玻璃桥  5.0     1.0   52
# 755    珠海                                                白沙滩  5.0     1.0   52
# 2319   琼海                                    万佛塔Wanfo Pagoda  5.0     0.5   52
# 2377   白城                         汉书遗址Book of Han Relic Site  5.0     1.0   52
# 26     眉山                                             眉州活力小镇  5.0     1.0   52
# 1752   福州                                 东庠岛Dongtang Island  5.0     2.0   52
# 943    贵阳                                              翁洞滩瀑布  5.0     1.0   52
# 1393   贺州                                              古镇石板街  5.0     1.0   52
# 1107   运城                        东下冯遗址Dongxiafeng Relic Site  5.0     1.0   52
# 2286   通化  辉南县朝阳镇永胜赞美教堂Huinanxian Zhaoyangzhen Yongsheng ...  5.0     1.0   52
# 1314   邵阳                                            简家陇飞行营地  5.0     1.0  680
# 2197   阜新           Aun Tong Coffee MillAun Tong Coffee Mill  5.0     1.0   52

# %% [markdown]
# ### 步骤 4：计算和分析
#
# 9. 计算城市间的地理距离：
#    - 使用Haversine公式计算城市间的地理距离。
#    - Haversine公式:
#      $$
#      d = 2R \cdot \arcsin\left(\sqrt{\sin^2\left(\frac{\Delta\phi}{2}\right) + \cos(\phi_1) \cdot \cos(\phi_2) \cdot \sin^2\left(\frac{\Delta\lambda}{2}\right)}\right)
#      $$
#   其中：
#      $$
#      \Delta\phi = \phi_2 - \phi_1
#      $$
#      $$
#      \Delta\lambda = \lambda_2 - \lambda_1
#      $$
#   $\phi$ 是纬度，$\lambda$ 是经度，$R$ 是地球半径（约6371公里）。
# 10. 计算旅行时间和成本：
#     - 基于地理距离，计算旅行时间（假设高铁速度为300公里/小时）。
#       $$
#       \text{TravelTime (hours)} = \frac{\text{Distance (km)}}{300}
#       $$
#     基于地理距离，计算高铁旅行成本（假设每公里票价为0.48到0.74元的平均值）。
#       $$
#       \text{TravelCost (￥)} = \text{Distance (km)} \times \frac{0.48 + 0.74}{2}
#       $$
#
# ### 步骤 5：构建城市间的图并规划游玩路线
#
# 11. 构建城市间的图：
#     - 使用NetworkX构建城市间的图，边权重为旅行时间和旅行成本。
# 12. 规划游玩路线：
#     - 使用启发式算法规划游玩路线，考虑时间限制、旅行时间和游玩时间。
#     - 计算总花费时间和费用，并输出游玩的城市数量。
#
# ### 启发式算法详细原理和步骤
#
# 1. 初始化参数：
#    - 设置起始城市（如“惠州”）。
#    - 设置时间限制（如144小时），并扣除初始到达时间和休息时间。
#      $$
#      \text{time\_limit} = 144 \text{小时} - \text{travel\_time\_to\_start} - \text{sleep\_time}
#      $$
#    - 初始化总旅行时间和总费用。
#    - 初始化已访问城市列表。
# 2. 迭代寻找下一个城市：
#    - 当前城市从未访问城市中选择邻居城市，计算旅行时间和游玩时间。
#      $$
#      \text{neighbors} = \left\{ \text{neighbor} \mid \text{neighbor} \notin \text{visited\_cities} \right\}
#      $$
#    - 按照高铁车程时间升序排序，选择时间最短的下一个城市。
#      $$
#      \text{next\_city} = \min(\text{neighbors}, \text{key} = \text{travel\_time})
#      $$
#    - 计算到下一个城市的游玩时间和门票费用。
# 3. 检查时间限制：
#    - 判断是否在剩余时间内可以游玩下一个城市。
#      $$
#      \text{if } \text{total\_travel\_time} + \text{travel\_time} + \text{visit\_time} + \text{waste\_time} > \text{time\_limit} \text{ then break}
#      $$
#    - 如果可以，更新总时间和总费用，添加城市到已访问列表。
#      $$
#      \text{total\_travel\_time} += \text{travel\_time} + \text{visit\_time} + \text{waste\_time}
#      $$
#      $$
#      \text{total\_cost} += \text{travel\_cost} + \text{transport\_cost}
#      $$
#      $$
#      \text{visited\_cities.append(next\_city)}
#      $$
#    - 如果不可以，结束迭代。
# 4. 输出结果：
#    - 输出规划的游玩路线，包括总花费时间、总费用和游玩的城市数量。

# %%
import networkx as nx
from math import radians, sin, cos, sqrt, atan2

# Haversine公式计算地理距离
def haversine(lon1, lat1, lon2, lat2):
    R = 6371.0  # 地球半径，单位为公里
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# 计算城市间的地理距离并生成DataFrame
distances = [
    [city1['城市'], city2['城市'], haversine(city1['longitude'], city1['latitude'], city2['longitude'], city2['latitude'])]
    for i, city1 in filtered50_df.iterrows()
    for j, city2 in filtered50_df.iterrows()
    if city1['城市'] != city2['城市']
]

city_distances = pd.DataFrame(distances, columns=['City1', 'City2', 'Distance (km)'])

# 计算旅行时间和成本
# 高铁票价是根据实际行驶的公里数来计算的。一般来说，票价为每公里0.48元到0.74元不等，具体取决于列车类型和座位等级。
city_distances['TravelTime (hours)'] = city_distances['Distance (km)'] / 300
city_distances['TravelCost (￥)'] = city_distances['Distance (km)'] * (0.48 + 0.74) / 2

# 输出结果
city_distances
# Out:
#      City1 City2  Distance (km)  TravelTime (hours)  TravelCost (￥)
# 0      嘉峪关    白城    1396.971092            4.656570      852.152366
# 1      嘉峪关    中山    2089.479739            6.964932     1274.582641
# 2      嘉峪关    运城    1618.602535            5.395342      987.347547
# 3      嘉峪关    潜江    1685.849330            5.619498     1028.368091
# 4      嘉峪关    扬州    2064.576287            6.881921     1259.391535
# ...    ...   ...            ...                 ...             ...
# 1887    宝鸡   佳木斯    2374.339648            7.914465     1448.347185
# 1888    宝鸡    阜新    1517.152481            5.057175      925.463014
# 1889    宝鸡    包头     735.491547            2.451638      448.649844
# 1890    宝鸡   攀枝花    1014.020097            3.380067      618.552259
# 1891    宝鸡    贺州    1184.347866            3.947826      722.452198
#
# [1892 rows x 5 columns]

# %%
# 构建城市间的图
G = nx.Graph()
for _, row in city_distances.iterrows():
    G.add_edge(row['City1'], row['City2'], weight=[row['TravelTime (hours)'], row['TravelCost (￥)']])
dist = haversine(113.2644, 23.0691, filtered50_df[filtered50_df['城市']=='惠州']['longitude'], filtered50_df[filtered50_df['城市']=='惠州']['latitude'])
time = dist/300
dist, time
# Out:
# (117.80874501634047, 0.3926958167211349)

# %%
# 初始化起点和时间限制
# start_city = '广州'
start_city = '惠州'
# time_limit = 144 # 小时
sleep_time = 6*8
time_limit = 144 - time - sleep_time  # 小时
total_travel_time = 0
total_cost = 0 + dist * (0.48+0.74)/2
visited_cities = [start_city]
waste_time = 3

# %%
# 启发式算法规划游玩路线
current_city = start_city
while total_travel_time < time_limit:
    # 查找当前城市能到达的城市及其高铁车程时间
    neighbors = [(neighbor, G.edges[current_city, neighbor]['weight']) for neighbor in G.neighbors(current_city) if neighbor not in visited_cities]
    
    if not neighbors:
        break

    # 按高铁车程时间升序排序，选择时间最短的下一个城市
    neighbors.sort(key=lambda x: x[1])
    next_city, (travel_time, transport_cost) = neighbors[0]
    
    # 找到下一个城市的最短游玩时间
    if shortest_visit_time_df[shortest_visit_time_df['City'] == next_city]['建议游玩时间'].values:
        visit_time = shortest_visit_time_df[shortest_visit_time_df['City'] == next_city]['建议游玩时间'].values[0]
        travel_cost = shortest_visit_time_df[shortest_visit_time_df['City'] == next_city]['门票'].values[0]
    else:
        visit_time = 2
        travel_cost = 0
    
    # 判断是否在剩余时间内可以游玩下一个城市
    if total_travel_time + travel_time + visit_time + waste_time > time_limit:
        break

    # 更新总时间和总费用
    total_travel_time += travel_time + visit_time + waste_time 
    total_cost += travel_cost + transport_cost
    visited_cities.append(next_city)
    current_city = next_city

# 输出规划的游玩路线
print("游玩路线：", " -> ".join(visited_cities))
print("总花费时间：", total_travel_time + sleep_time, "小时")
print("总花费费用：", total_cost , "￥")
print("游玩的城市数量：", len(visited_cities) - 1)
# Out:
# 游玩路线： 惠州 -> 汕尾 -> 珠海 -> 贺州 -> 中山 -> 邵阳 -> 常德 -> 潜江 -> 咸宁 -> 眉山 -> 安庆 -> 福州 -> 杭州 -> 扬州 -> 台州 -> 宿迁
# 总花费时间： 143.0714706481641 小时
# 总花费费用： 3259.442463073998 ￥
# 游玩的城市数量： 15

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置自定义字体路径
font_path = '/System/Library/Fonts/PingFang.ttc'
font_prop = fm.FontProperties(fname=font_path)

# 设置中文字体
plt.rcParams['font.sans-serif'] = [font_prop.get_name()]
plt.rcParams['axes.unicode_minus'] = False  # 解决坐标轴负数显示问题

# 构建包含城市及其经纬度的DataFrame
city_coords = filtered50_df.set_index('城市').loc[visited_cities]

# 创建绘制图
plt.figure(figsize=(12, 8))

# 创建NetworkX图
G = nx.DiGraph()

# 添加节点和边
for city in visited_cities:
    G.add_node(city, pos=(city_coords.loc[city, 'longitude'], city_coords.loc[city, 'latitude']))

for i in range(len(visited_cities) - 1):
    G.add_edge(visited_cities[i], visited_cities[i + 1])

# 获取节点位置
pos = nx.get_node_attributes(G, 'pos')

# 绘制节点和边
node_colors = ['lightgreen' if city in visited_cities else 'skyblue' for city in G.nodes()]
nx.draw(G, pos, with_labels=False, node_size=1000, node_color=node_colors, edge_color="gray")

# 绘制路线
path_edges = list(zip(visited_cities[:-1], visited_cities[1:]))
nx.draw_networkx_edges(G, pos, edgelist=path_edges, edge_color='red', arrows=True)

# 添加标签
nx.draw_networkx_labels(G, pos, labels=dict(zip(visited_cities, visited_cities)), font_size=14, font_weight="bold", font_family=font_prop.get_name())

# 设置标题
plt.title("城市游玩路线图", fontproperties=font_prop, fontsize=20)
plt.xlabel("经度", fontproperties=font_prop, fontsize=16)
plt.ylabel("纬度", fontproperties=font_prop, fontsize=16)

# 添加网格和背景
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)  # 灰色网格
plt.gca().set_facecolor('lightyellow')  # 浅黄色背景

# 显示图
plt.show()

# %%
# 创建绘制图
plt.figure(figsize=(12, 8))

# 创建 Basemap 地图
m = Basemap(projection='merc', llcrnrlat=15, urcrnrlat=55, llcrnrlon=70, urcrnrlon=140, resolution='i')
m.drawcoastlines()
m.drawcountries()
m.drawmapboundary(fill_color='aqua')
m.fillcontinents(color='lightyellow', lake_color='aqua')
m.drawparallels(range(0, 90, 10), labels=[1,0,0,0])
m.drawmeridians(range(0, 180, 10), labels=[0,0,0,1])

# 在地图上添加城市标记
for _, city in filtered50_df.iterrows():
    x, y = m(city['longitude'], city['latitude'])
    m.plot(x, y, 'bo', markersize=8)
    plt.text(x, y, city['城市'], fontsize=12, fontproperties=font_prop, ha='left', va='bottom')

# 在地图中标出广州
x, y = m(113.2644, 23.1291)
m.plot(x, y, 'ro', markersize=10)
plt.text(x, y, '广州', fontsize=14, fontproperties=font_prop, ha='left', va='bottom', color='red')

# 添加路线
coords = [(filtered50_df[filtered50_df['城市'] == city]['latitude'].values[0], filtered50_df[filtered50_df['城市'] == city]['longitude'].values[0]) for city in visited_cities]
route_x, route_y = zip(*[m(lon, lat) for lat, lon in coords])
m.plot(route_x, route_y, color='green', linewidth=2.5, linestyle='-', marker='o', markersize=5)

# 设置标题
plt.title("中国城市游玩路线图", fontsize=20, fontproperties=font_prop)

# 显示图
plt.show()
